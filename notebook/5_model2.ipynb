# %%
import pandas as pd
import numpy as np

from imblearn.combine import SMOTETomek
from imblearn.combine import SMOTEENN

# librerías para crear el modelo
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn import tree

# para calcular las métricas
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import f1_score 
from sklearn.metrics import cohen_kappa_score


from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier


from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
df_yesno_scaled = pd.read_csv('data/df_yesno_scaled2.csv')

# %%
df_yesno_scaled[df_yesno_scaled['Offer Accepted']== 'No'].shape
# Out:
# (0, 18)

# %% [markdown]
# # Imbalance
# There is a great imbalance between the Yes and No in 'Offer Accepted' column. To deal with this we'll combine upsampling and downsampling techniques that generate synthetic data points of minority class samples in the neighborhood of minority class samples and then removing samples which do not agree “enough” with their neighboorhood.

# %%
df_yesno_scaled.columns
# Out:
# Index(['Offer Accepted', 'Reward_Air Miles', 'Reward_Cash Back',
#        'Reward_Points', 'Mailer Type_Letter', 'Mailer Type_Postcard',
#        'Income Level_High', 'Income Level_Low', 'Income Level_Medium',
#        'Overdraft Protection_No', 'Overdraft Protection_Yes',
#        'Credit Rating_High', 'Credit Rating_Low', 'Credit Rating_Medium',
#        'Own Your Home_No', 'Own Your Home_Yes', 'PC1', 'PC2'],
#       dtype='object')

# %%
X = df_yesno_scaled[['Reward_Air Miles', 'Reward_Cash Back',
       'Reward_Points', 'Mailer Type_Letter', 'Mailer Type_Postcard',
       'Income Level_High', 'Income Level_Low', 'Income Level_Medium',
       'Overdraft Protection_No', 'Overdraft Protection_Yes',
       'Credit Rating_High', 'Credit Rating_Low', 'Credit Rating_Medium',
       'Own Your Home_No', 'Own Your Home_Yes', 'PC1', 'PC2']]
y = df_yesno_scaled['Offer Accepted']

# %%
smt = SMOTETomek()
X_resampled, y_resampled = smt.fit_resample(X, y)

# %%
y_resampled.value_counts()
# Out:
# 1    15970
# 0    15970
# Name: Offer Accepted, dtype: int64

# %% [markdown]
# # Model

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size = 0.2, 
                                                    random_state = 80)

# %%
y_train.describe()
# Out:
# count    25552.000000
# mean         0.499100
# std          0.500009
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: Offer Accepted, dtype: float64

# %%
y_test.describe()
# Out:
# count    6388.000000
# mean        0.503601
# std         0.500026
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Offer Accepted, dtype: float64

# %%
def metricas(clases_reales_test, clases_predichas_test, clases_reales_train, clases_predichas_train, modelo):
    
    # para el test
    accuracy_test = accuracy_score(clases_reales_test, clases_predichas_test)
    precision_test = precision_score(clases_reales_test, clases_predichas_test)
    recall_test = recall_score(clases_reales_test, clases_predichas_test)
    f1_test = f1_score(clases_reales_test, clases_predichas_test)
    kappa_test = cohen_kappa_score(clases_reales_test, clases_predichas_test)

    # para el train
    accuracy_train = accuracy_score(clases_reales_train, clases_predichas_train)
    precision_train = precision_score(clases_reales_train, clases_predichas_train)
    recall_train = recall_score(clases_reales_train, clases_predichas_train)
    f1_train = f1_score(clases_reales_train, clases_predichas_train)
    kappa_train = cohen_kappa_score(clases_reales_train, clases_predichas_train)
    

    
    df = pd.DataFrame({"accuracy": [accuracy_test, accuracy_train], 
                       "precision": [precision_test, precision_train],
                       "recall": [recall_test, recall_train], 
                       "f1": [f1_test, f1_train],
                       "kapppa": [kappa_test, kappa_train],
                       "set": ["test", "train"]})
    
    df["modelo"] = modelo
    return df

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression(max_iter = 100000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=100000)

# %%
y_pred_lr_test = lr.predict(X_test)
y_pred_lr_train = lr.predict(X_train)

# %% [markdown]
# Let's check the accuracy of our model on the test set.

# %%
def matriz_confusion(clases_reales, clases_predichas, total_filas_test):
    mat_lr = confusion_matrix(clases_reales, clases_predichas)

    df = pd.DataFrame(mat_lr, columns = ["No", "Yes"], index = ["No", "Yes"])
    df = ((df / total_filas_test) * 100).round(2)
    return df

# %%
results_logistic_regression = metricas(y_test, y_pred_lr_test, y_train, y_pred_lr_train, "Logistic Regression" )
results_logistic_regression
# Out:
#    accuracy  precision    recall        f1    kapppa    set  \
# 0  0.821540   0.831683  0.809450  0.820416  0.643131   test
# 1  0.831833   0.836785  0.823728  0.830205  0.663656  train
#
#                 modelo
# 0  Logistic Regression
# 1  Logistic Regression

# %%
matriz_logistica = matriz_confusion(y_test, y_pred_lr_test, y_test.shape[0])
matriz_logistica
# Out:
#         No    Yes
# No   41.39   8.25
# Yes   9.60  40.76

# %% [markdown]
# ### Decision Tree

# %%
arbol = DecisionTreeClassifier()
arbol.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
max_features = np.sqrt(len(X_train.columns))
max_features
# Out:
# 4.123105625617661

# %%
y_pred_train_dt = arbol.predict(X_train)
y_pred_test_dt = arbol.predict(X_test)

# %%
results_decission_tree1 = metricas(y_test, y_pred_test_dt,y_train, y_pred_train_dt, "Decission Tree I" )
results_decission_tree1
# Out:
#    accuracy  precision    recall        f1   kapppa    set            modelo
# 0   0.90263   0.894977  0.913895  0.904337  0.80522   test  Decission Tree I
# 1   1.00000   1.000000  1.000000  1.000000  1.00000  train  Decission Tree I

# %%
matriz_logistica = matriz_confusion(y_test, y_pred_test_dt, y_test.shape[0])
matriz_logistica
# Out:
#         No    Yes
# No   44.24   5.40
# Yes   4.34  46.02

# %%
print(arbol.tree_.max_depth)
# Out:
# 31

# %%
param = {"max_depth": [15,16,17,18,19,20,21],
         "min_samples_split": [10, 50, 100],
         "max_features": [10, 11, 12, 13, 14, 15]}

arbol2 = GridSearchCV(
        estimator = DecisionTreeClassifier(), 
        param_grid = param, 
        verbose = 3, 
        cv = 10, 
        return_train_score = True, 
        scoring = "neg_mean_squared_error")

# %%
arbol2.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# [CV 1/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.077, test=-0.121) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.074, test=-0.125) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.073, test=-0.116) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.082, test=-0.119) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.076, test=-0.125) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.074, test=-0.116) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.075, test=-0.132) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.071, test=-0.122) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.073, test=-0.114) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.068, test=-0.118) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.108, test=-0.127) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.116, test=-0.158) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.118, test=-0.148) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.115, test=-0.152) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.112, test=-0.139) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.118, test=-0.153) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.114, test=-0.141) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.115, test=-0.136) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.118, test=-0.142) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.117, test=-0.147) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.135, test=-0.150) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.133, test=-0.162) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.137, test=-0.156) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.146, test=-0.167) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.146, test=-0.157) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.141, test=-0.171) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.140, test=-0.156) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.139, test=-0.160) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.146, test=-0.159) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.139, test=-0.162) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.080, test=-0.122) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.077, test=-0.130) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.079, test=-0.115) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.071, test=-0.118) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.076, test=-0.121) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.076, test=-0.121) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.074, test=-0.112) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.079, test=-0.119) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.074, test=-0.115) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.067, test=-0.112) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.113, test=-0.127) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.118, test=-0.156) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.116, test=-0.149) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.116, test=-0.133) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.114, test=-0.143) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.110, test=-0.142) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.112, test=-0.142) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.109, test=-0.139) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.112, test=-0.138) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.112, test=-0.146) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.141, test=-0.160) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.139, test=-0.171) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.138, test=-0.158) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.139, test=-0.161) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.143, test=-0.157) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.145, test=-0.169) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.137, test=-0.162) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.140, test=-0.163) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.138, test=-0.156) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.139, test=-0.156) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.072, test=-0.119) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.074, test=-0.128) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.079, test=-0.121) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.080, test=-0.123) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.073, test=-0.124) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.072, test=-0.124) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.071, test=-0.115) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.072, test=-0.122) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.069, test=-0.113) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.071, test=-0.129) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.110, test=-0.129) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.108, test=-0.139) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.111, test=-0.135) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.114, test=-0.143) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.116, test=-0.139) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.111, test=-0.138) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.113, test=-0.147) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.111, test=-0.137) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.111, test=-0.131) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.117, test=-0.150) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.138, test=-0.157) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.138, test=-0.172) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.138, test=-0.154) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.135, test=-0.152) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.137, test=-0.152) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.144, test=-0.164) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.140, test=-0.153) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.143, test=-0.164) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.136, test=-0.149) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.139, test=-0.162) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.069, test=-0.113) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.074, test=-0.126) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.068, test=-0.112) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.069, test=-0.121) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.062, test=-0.115) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.072, test=-0.117) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.061, test=-0.115) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.067, test=-0.114) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.075, test=-0.114) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.073, test=-0.119) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.112, test=-0.141) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.110, test=-0.151) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.112, test=-0.134) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.114, test=-0.144) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.115, test=-0.143) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.113, test=-0.143) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.110, test=-0.145) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.113, test=-0.143) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.110, test=-0.124) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.113, test=-0.153) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.138, test=-0.148) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.139, test=-0.170) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.136, test=-0.157) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.140, test=-0.164) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.134, test=-0.157) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.137, test=-0.160) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.138, test=-0.157) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.136, test=-0.153) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.137, test=-0.152) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.137, test=-0.163) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.065, test=-0.113) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.073, test=-0.130) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.069, test=-0.118) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.073, test=-0.114) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.072, test=-0.121) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.071, test=-0.128) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.068, test=-0.118) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.072, test=-0.127) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.071, test=-0.114) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.066, test=-0.126) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.108, test=-0.131) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.112, test=-0.147) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.118, test=-0.140) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.112, test=-0.136) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.111, test=-0.137) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.113, test=-0.139) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.109, test=-0.150) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.111, test=-0.138) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.117, test=-0.143) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.113, test=-0.147) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.134, test=-0.145) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.135, test=-0.166) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.134, test=-0.158) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.135, test=-0.163) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.135, test=-0.153) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.136, test=-0.164) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.136, test=-0.163) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.136, test=-0.157) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.144) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.139, test=-0.168) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.066, test=-0.110) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.071, test=-0.124) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.070, test=-0.109) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.072, test=-0.115) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.071, test=-0.122) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.069, test=-0.123) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.066, test=-0.114) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.065, test=-0.115) total time=   0.1s
# [CV 9/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.074, test=-0.113) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.071, test=-0.120) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.107, test=-0.133) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.110, test=-0.151) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.113, test=-0.133) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.113, test=-0.139) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.114, test=-0.137) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.109, test=-0.141) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.107, test=-0.141) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.113, test=-0.146) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.115, test=-0.137) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.110, test=-0.146) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.131, test=-0.145) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.131, test=-0.165) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.135, test=-0.153) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.138, test=-0.164) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.139, test=-0.162) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.138, test=-0.159) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.134, test=-0.162) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.140, test=-0.168) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.134, test=-0.146) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.136, test=-0.161) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.068, test=-0.120) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.067, test=-0.119) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.063, test=-0.111) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.067, test=-0.112) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.066, test=-0.112) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.069, test=-0.117) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.065, test=-0.115) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.067, test=-0.114) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.061, test=-0.102) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.067, test=-0.114) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.109, test=-0.132) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.115, test=-0.161) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.108, test=-0.130) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.118, test=-0.144) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.110, test=-0.140) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.113, test=-0.140) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.110, test=-0.137) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.112, test=-0.133) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.111, test=-0.127) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.115, test=-0.146) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.142, test=-0.160) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.141, test=-0.172) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.139, test=-0.160) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.140, test=-0.163) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.142, test=-0.162) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.139, test=-0.158) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.139, test=-0.162) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.139, test=-0.160) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.142, test=-0.148) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.143, test=-0.164) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.062, test=-0.113) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.063, test=-0.119) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.069, test=-0.115) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.062, test=-0.107) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.068, test=-0.119) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.063, test=-0.112) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.055, test=-0.113) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.069, test=-0.121) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.068, test=-0.114) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.059, test=-0.115) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.108, test=-0.134) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.113, test=-0.160) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.106, test=-0.127) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.110, test=-0.144) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.114, test=-0.144) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.115, test=-0.143) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.113, test=-0.146) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.116, test=-0.138) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.113, test=-0.136) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.109, test=-0.137) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.140, test=-0.152) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.134, test=-0.162) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.139, test=-0.157) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.142, test=-0.161) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.142, test=-0.160) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.137, test=-0.168) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.139, test=-0.151) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.135, test=-0.152) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.134, test=-0.138) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.142, test=-0.177) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.064, test=-0.108) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.070, test=-0.125) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.070, test=-0.117) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.072, test=-0.129) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.060, test=-0.109) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.065, test=-0.120) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.064, test=-0.111) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.065, test=-0.113) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.069, test=-0.117) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.065, test=-0.109) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.113, test=-0.135) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.106, test=-0.144) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.107, test=-0.136) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.116, test=-0.144) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.109, test=-0.136) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.114, test=-0.148) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.111, test=-0.150) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.113, test=-0.137) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.111, test=-0.134) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.110, test=-0.144) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.133, test=-0.153) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.136, test=-0.166) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.138, test=-0.153) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.142, test=-0.159) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.139, test=-0.153) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.138, test=-0.165) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.142, test=-0.159) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.137, test=-0.151) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.138, test=-0.151) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.135, test=-0.159) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.060, test=-0.105) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.066, test=-0.126) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.067, test=-0.119) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.067, test=-0.116) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.054, test=-0.105) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.064, test=-0.117) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.065, test=-0.112) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.066, test=-0.111) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.064, test=-0.116) total time=   0.1s
# [CV 10/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.059, test=-0.121) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.110, test=-0.138) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.110, test=-0.149) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.113, test=-0.133) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.107, test=-0.135) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.109, test=-0.142) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.112, test=-0.150) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.106, test=-0.141) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.106, test=-0.138) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.114, test=-0.133) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.109, test=-0.154) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.134, test=-0.149) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.134, test=-0.170) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.137, test=-0.162) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.136, test=-0.163) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.135, test=-0.155) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.137, test=-0.167) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.136, test=-0.153) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.131, test=-0.154) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.136, test=-0.148) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.139, test=-0.166) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.063, test=-0.112) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.062, test=-0.125) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.065, test=-0.108) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.068, test=-0.117) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.063, test=-0.120) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.065, test=-0.110) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.056, test=-0.116) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.058, test=-0.111) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.063, test=-0.114) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.061, test=-0.115) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.109, test=-0.140) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.113, test=-0.157) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.105, test=-0.132) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.113, test=-0.138) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.109, test=-0.134) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.105, test=-0.140) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.110, test=-0.141) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.108, test=-0.142) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.112, test=-0.132) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.108, test=-0.142) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.131, test=-0.147) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.136, test=-0.165) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.156) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.139, test=-0.169) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.137, test=-0.153) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.137, test=-0.160) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.136, test=-0.164) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.133, test=-0.151) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.137, test=-0.159) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.138, test=-0.175) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.061, test=-0.114) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.062, test=-0.117) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.064, test=-0.112) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.067, test=-0.115) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.063, test=-0.116) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.060, test=-0.125) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.060, test=-0.119) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.061, test=-0.113) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.069, test=-0.112) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.063, test=-0.120) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.107, test=-0.131) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.108, test=-0.144) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.116, test=-0.142) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.109, test=-0.137) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.106, test=-0.135) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.105, test=-0.140) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.103, test=-0.130) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.110, test=-0.139) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.105, test=-0.124) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.109, test=-0.151) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.132, test=-0.149) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.142, test=-0.172) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.138, test=-0.156) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.132, test=-0.160) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.135, test=-0.156) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.136, test=-0.158) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.134, test=-0.162) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.131, test=-0.155) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.136, test=-0.153) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.139, test=-0.162) total time=   0.0s
# [CV 1/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.061, test=-0.115) total time=   0.0s
# [CV 2/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.059, test=-0.120) total time=   0.0s
# [CV 3/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.060, test=-0.111) total time=   0.0s
# [CV 4/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.061, test=-0.104) total time=   0.0s
# [CV 5/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.056, test=-0.110) total time=   0.0s
# [CV 6/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.056, test=-0.119) total time=   0.0s
# [CV 7/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.059, test=-0.110) total time=   0.0s
# [CV 8/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.060, test=-0.100) total time=   0.0s
# [CV 9/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.061, test=-0.102) total time=   0.0s
# [CV 10/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.060, test=-0.107) total time=   0.0s
# [CV 1/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.107, test=-0.142) total time=   0.0s
# [CV 2/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.109, test=-0.147) total time=   0.0s
# [CV 3/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.112, test=-0.133) total time=   0.0s
# [CV 4/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.110, test=-0.135) total time=   0.0s
# [CV 5/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.106, test=-0.139) total time=   0.0s
# [CV 6/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.106, test=-0.134) total time=   0.0s
# [CV 7/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.108, test=-0.150) total time=   0.0s
# [CV 8/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.109, test=-0.144) total time=   0.0s
# [CV 9/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.113, test=-0.131) total time=   0.0s
# [CV 10/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.107, test=-0.141) total time=   0.0s
# [CV 1/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.136, test=-0.154) total time=   0.0s
# [CV 2/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.139, test=-0.163) total time=   0.0s
# [CV 3/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.138, test=-0.152) total time=   0.0s
# [CV 4/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.136, test=-0.157) total time=   0.0s
# [CV 5/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.139, test=-0.151) total time=   0.0s
# [CV 6/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.143, test=-0.168) total time=   0.0s
# [CV 7/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.140, test=-0.155) total time=   0.0s
# [CV 8/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.141, test=-0.164) total time=   0.0s
# [CV 9/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.144, test=-0.157) total time=   0.0s
# [CV 10/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.138, test=-0.161) total time=   0.0s
# [CV 1/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.056, test=-0.102) total time=   0.0s
# [CV 2/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.063, test=-0.120) total time=   0.0s
# [CV 3/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.055, test=-0.114) total time=   0.0s
# [CV 4/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.057, test=-0.110) total time=   0.0s
# ...
# [CV 3/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.133, test=-0.151) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.146, test=-0.169) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.138, test=-0.151) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.131, test=-0.156) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.138, test=-0.155) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.133, test=-0.156) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.135, test=-0.141) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.135, test=-0.164) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.040, test=-0.108) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.044, test=-0.121) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.045, test=-0.103) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.047, test=-0.112) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.045, test=-0.108) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.041, test=-0.103) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.041, test=-0.107) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.042, test=-0.116) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.045, test=-0.112) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.041, test=-0.115) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.105, test=-0.130) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.108, test=-0.159) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.109, test=-0.135) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.108, test=-0.148) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.106, test=-0.149) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.105, test=-0.139) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.108, test=-0.150) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.111, test=-0.141) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.107, test=-0.138) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.104, test=-0.139) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.134, test=-0.156) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.137, test=-0.177) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.132, test=-0.153) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.140, test=-0.165) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.138, test=-0.149) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.135, test=-0.162) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.136, test=-0.153) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.134, test=-0.174) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.137, test=-0.155) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.135, test=-0.157) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.045, test=-0.109) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.043, test=-0.118) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.045, test=-0.114) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.041, test=-0.111) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.045, test=-0.115) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.047, test=-0.115) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.041, test=-0.103) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.042, test=-0.101) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.045, test=-0.116) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.045, test=-0.121) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.105, test=-0.142) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.107, test=-0.146) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.106, test=-0.133) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.109, test=-0.137) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.113, test=-0.142) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.106, test=-0.143) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.106, test=-0.149) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.103, test=-0.136) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.105, test=-0.129) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.108, test=-0.141) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.135, test=-0.157) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.140, test=-0.173) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.138, test=-0.160) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.139, test=-0.171) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.137, test=-0.155) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.133, test=-0.157) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.134, test=-0.163) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.133, test=-0.158) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.136, test=-0.159) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.136, test=-0.151) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.044, test=-0.106) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.044, test=-0.114) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.042, test=-0.105) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.046, test=-0.109) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.044, test=-0.114) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.044, test=-0.115) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.042, test=-0.112) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.043, test=-0.106) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.045, test=-0.099) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.045, test=-0.107) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.107, test=-0.137) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.104, test=-0.144) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.104, test=-0.131) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.106, test=-0.146) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.109, test=-0.140) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.108, test=-0.148) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.140) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.106, test=-0.144) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.103, test=-0.127) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.108, test=-0.142) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.134, test=-0.160) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.172) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.135, test=-0.162) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.135, test=-0.159) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.134, test=-0.151) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.133, test=-0.157) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.134, test=-0.163) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.137, test=-0.162) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.134, test=-0.147) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.140, test=-0.164) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.042, test=-0.104) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.040, test=-0.113) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.044, test=-0.113) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.043, test=-0.106) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.042, test=-0.103) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.045, test=-0.117) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.041, test=-0.102) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.042, test=-0.115) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.044, test=-0.094) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.043, test=-0.112) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.103, test=-0.142) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.102, test=-0.143) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.106, test=-0.135) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.106, test=-0.141) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.106, test=-0.140) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.102, test=-0.141) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.106, test=-0.142) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.102, test=-0.133) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.103, test=-0.132) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.109, test=-0.153) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.135, test=-0.154) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.134, test=-0.174) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.133, test=-0.155) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.134, test=-0.154) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.132, test=-0.153) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.134, test=-0.169) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.136, test=-0.161) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.135, test=-0.158) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.132, test=-0.151) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.133, test=-0.156) total time=   0.0s
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [16, 17, 18, 19, 20, 21],
#                          'max_features': [10, 11, 12, 13, 14, 15],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
arbol2.best_params_
# Out:
# {'max_depth': 21, 'max_features': 10, 'min_samples_split': 10}

# %%
arbol3 = DecisionTreeClassifier( max_depth = 10, max_features = 10, min_samples_split=10)
arbol3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, max_features=10, min_samples_split=10)

# %%
y_pred_train_dt = arbol3.predict(X_train)
y_pred_test_dt = arbol3.predict(X_test)

# %%
results_decission_tree2 = metricas(y_test, y_pred_test_dt, y_train, y_pred_train_dt, "Decission Tree II" )
results_decission_tree2
# Out:
#    accuracy  precision    recall        f1    kapppa    set             modelo
# 0  0.827332   0.787697  0.899596  0.839936  0.654291   test  Decission Tree II
# 1  0.841265   0.798435  0.912256  0.851559  0.682610  train  Decission Tree II

# %%
matriz_logistica = matriz_confusion(y_test, y_pred_test_dt, y_test.shape[0])
matriz_logistica
# Out:
#         No    Yes
# No   43.35   6.29
# Yes   4.56  45.80

# %% [markdown]
# ### Random Forest

# %%
random_forest = GridSearchCV(
        estimator = RandomForestClassifier(), 
        param_grid = param, 
        verbose = 3, 
        cv = 10, 
        return_train_score = True, 
        scoring = "neg_mean_squared_error")

# %%
random_forest.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# [CV 1/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.053, test=-0.088) total time=   3.2s
# [CV 2/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.052, test=-0.095) total time=   3.2s
# [CV 3/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.053, test=-0.085) total time=   3.0s
# [CV 4/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.055, test=-0.088) total time=   2.9s
# [CV 5/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.053, test=-0.090) total time=   3.2s
# [CV 6/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.052, test=-0.092) total time=   3.5s
# [CV 7/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.054, test=-0.091) total time=   3.6s
# [CV 8/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.053, test=-0.090) total time=   3.5s
# [CV 9/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.054, test=-0.082) total time=   3.3s
# [CV 10/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.053, test=-0.094) total time=   3.1s
# [CV 1/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.099, test=-0.119) total time=   2.9s
# [CV 2/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.097, test=-0.130) total time=   3.2s
# [CV 3/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.096, test=-0.118) total time=   2.9s
# [CV 4/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.097, test=-0.118) total time=   3.0s
# [CV 5/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.098, test=-0.116) total time=   2.8s
# [CV 6/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.097, test=-0.120) total time=   2.8s
# [CV 7/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.097, test=-0.118) total time=   2.8s
# [CV 8/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.098, test=-0.123) total time=   2.9s
# [CV 9/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.097, test=-0.107) total time=   3.0s
# [CV 10/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.097, test=-0.126) total time=   3.0s
# [CV 1/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.127, test=-0.135) total time=   2.7s
# [CV 2/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.129, test=-0.160) total time=   2.8s
# [CV 3/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.129, test=-0.142) total time=   3.0s
# [CV 4/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.129, test=-0.146) total time=   2.9s
# [CV 5/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.125, test=-0.135) total time=   2.8s
# [CV 6/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.127, test=-0.143) total time=   2.7s
# [CV 7/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.129, test=-0.137) total time=   2.7s
# [CV 8/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.129, test=-0.154) total time=   2.7s
# [CV 9/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.127, test=-0.133) total time=   2.7s
# [CV 10/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.129, test=-0.148) total time=   2.9s
# [CV 1/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.052, test=-0.092) total time=   3.3s
# [CV 2/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.053, test=-0.098) total time=   3.2s
# [CV 3/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.055, test=-0.085) total time=   3.4s
# [CV 4/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.055, test=-0.090) total time=   3.2s
# [CV 5/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.053, test=-0.090) total time=   3.1s
# [CV 6/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.054, test=-0.095) total time=   3.4s
# [CV 7/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.054, test=-0.089) total time=   3.2s
# [CV 8/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.055, test=-0.090) total time=   3.2s
# [CV 9/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.056, test=-0.084) total time=   3.1s
# [CV 10/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.054, test=-0.096) total time=   3.3s
# [CV 1/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.099, test=-0.117) total time=   3.0s
# [CV 2/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.099, test=-0.129) total time=   3.0s
# [CV 3/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.099, test=-0.119) total time=   3.0s
# [CV 4/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.099, test=-0.118) total time=   3.0s
# [CV 5/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.097, test=-0.114) total time=   3.1s
# [CV 6/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.095, test=-0.120) total time=   3.0s
# [CV 7/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.100, test=-0.117) total time=   3.1s
# [CV 8/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.097, test=-0.124) total time=   3.1s
# [CV 9/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.097, test=-0.108) total time=   3.2s
# [CV 10/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.098, test=-0.124) total time=   2.9s
# [CV 1/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.126, test=-0.136) total time=   2.9s
# [CV 2/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.129, test=-0.156) total time=   3.1s
# [CV 3/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.130, test=-0.143) total time=   3.3s
# [CV 4/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.129, test=-0.143) total time=   3.0s
# [CV 5/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.129, test=-0.133) total time=   3.1s
# [CV 6/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.128, test=-0.138) total time=   3.1s
# [CV 7/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.130, test=-0.141) total time=   3.1s
# [CV 8/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.129, test=-0.153) total time=   3.3s
# [CV 9/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.126, test=-0.131) total time=   3.1s
# [CV 10/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.130, test=-0.152) total time=   3.0s
# [CV 1/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.053, test=-0.092) total time=   3.6s
# [CV 2/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.054, test=-0.100) total time=   4.0s
# [CV 3/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.053, test=-0.085) total time=   4.5s
# [CV 4/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.055, test=-0.093) total time=   4.8s
# [CV 5/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.056, test=-0.094) total time=   4.9s
# [CV 6/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.053, test=-0.093) total time=   4.2s
# [CV 7/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.055, test=-0.090) total time=   4.2s
# [CV 8/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.054, test=-0.090) total time=   4.4s
# [CV 9/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.055, test=-0.085) total time=   6.0s
# [CV 10/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.054, test=-0.098) total time=   5.1s
# [CV 1/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.099, test=-0.119) total time=   3.8s
# [CV 2/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.099, test=-0.132) total time=   3.6s
# [CV 3/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.100, test=-0.121) total time=   3.4s
# [CV 4/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.099, test=-0.122) total time=   3.5s
# [CV 5/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.097, test=-0.116) total time=   3.4s
# [CV 6/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.097, test=-0.124) total time=   3.4s
# [CV 7/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.099, test=-0.119) total time=   3.3s
# [CV 8/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.099, test=-0.127) total time=   3.4s
# [CV 9/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.101, test=-0.113) total time=   3.7s
# [CV 10/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.098, test=-0.124) total time=   3.4s
# [CV 1/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.128, test=-0.138) total time=   3.3s
# [CV 2/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.131, test=-0.162) total time=   3.6s
# [CV 3/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.130, test=-0.144) total time=   3.2s
# [CV 4/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.130, test=-0.148) total time=   3.3s
# [CV 5/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.129, test=-0.133) total time=   3.6s
# [CV 6/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.131, test=-0.141) total time=   3.5s
# [CV 7/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.131, test=-0.141) total time=   3.3s
# [CV 8/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.131, test=-0.155) total time=   3.4s
# [CV 9/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.127, test=-0.133) total time=   3.5s
# [CV 10/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.131, test=-0.151) total time=   3.5s
# [CV 1/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.054, test=-0.092) total time=   3.9s
# [CV 2/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.054, test=-0.100) total time=   3.8s
# [CV 3/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.054, test=-0.088) total time=   3.8s
# [CV 4/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.056, test=-0.095) total time=   4.0s
# [CV 5/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.053, test=-0.093) total time=   3.8s
# [CV 6/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.054, test=-0.096) total time=   3.8s
# [CV 7/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.054, test=-0.092) total time=   3.7s
# [CV 8/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.054, test=-0.091) total time=   4.1s
# [CV 9/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.057, test=-0.091) total time=   4.0s
# [CV 10/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.054, test=-0.095) total time=   4.0s
# [CV 1/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.102, test=-0.122) total time=   3.8s
# [CV 2/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.099, test=-0.134) total time=   3.5s
# [CV 3/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.102, test=-0.127) total time=   3.6s
# [CV 4/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.101, test=-0.120) total time=   4.0s
# [CV 5/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.100, test=-0.120) total time=   3.9s
# [CV 6/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.099, test=-0.121) total time=   3.7s
# [CV 7/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.101, test=-0.124) total time=   3.5s
# [CV 8/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.100, test=-0.128) total time=   3.4s
# [CV 9/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.100, test=-0.117) total time=   3.8s
# [CV 10/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.101, test=-0.130) total time=   3.5s
# [CV 1/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.129, test=-0.136) total time=   3.7s
# [CV 2/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.130, test=-0.164) total time=   3.6s
# [CV 3/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.131, test=-0.142) total time=   3.7s
# [CV 4/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.133, test=-0.151) total time=   3.4s
# [CV 5/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.129, test=-0.135) total time=   3.2s
# [CV 6/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.132, test=-0.144) total time=   3.4s
# [CV 7/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.130, test=-0.144) total time=   3.3s
# [CV 8/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.130, test=-0.155) total time=   3.4s
# [CV 9/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.128, test=-0.139) total time=   3.4s
# [CV 10/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.132, test=-0.151) total time=   3.4s
# [CV 1/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.053, test=-0.095) total time=   4.4s
# [CV 2/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.055, test=-0.105) total time=   4.5s
# [CV 3/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.054, test=-0.087) total time=   4.4s
# [CV 4/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.056, test=-0.095) total time=   5.1s
# [CV 5/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.055, test=-0.093) total time=   4.4s
# [CV 6/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.054, test=-0.097) total time=   5.4s
# [CV 7/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.055, test=-0.095) total time=   4.2s
# [CV 8/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.055, test=-0.093) total time=   4.6s
# [CV 9/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.057, test=-0.087) total time=   4.4s
# [CV 10/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=-0.054, test=-0.097) total time=   4.2s
# [CV 1/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.101, test=-0.124) total time=   4.0s
# [CV 2/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.133) total time=   4.0s
# [CV 3/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.102, test=-0.125) total time=   4.0s
# [CV 4/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.121) total time=   4.0s
# [CV 5/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.117) total time=   4.1s
# [CV 6/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.126) total time=   4.0s
# [CV 7/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.122) total time=   4.0s
# [CV 8/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.101, test=-0.126) total time=   4.3s
# [CV 9/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.115) total time=   4.8s
# [CV 10/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=-0.101, test=-0.130) total time=   5.7s
# [CV 1/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.128, test=-0.142) total time=   4.4s
# [CV 2/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.131, test=-0.160) total time=   4.8s
# [CV 3/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.130, test=-0.145) total time=   4.7s
# [CV 4/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.151) total time=   4.9s
# [CV 5/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.130, test=-0.134) total time=   4.9s
# [CV 6/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.144) total time=   4.8s
# [CV 7/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.131, test=-0.142) total time=   4.8s
# [CV 8/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.129, test=-0.155) total time=   4.7s
# [CV 9/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.128, test=-0.137) total time=   4.9s
# [CV 10/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.153) total time=   4.8s
# [CV 1/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.054, test=-0.095) total time=   5.4s
# [CV 2/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.055, test=-0.101) total time=   5.6s
# [CV 3/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.054, test=-0.089) total time=   5.6s
# [CV 4/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.055, test=-0.096) total time=   5.5s
# [CV 5/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.055, test=-0.094) total time=   5.5s
# [CV 6/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.052, test=-0.095) total time=   5.4s
# [CV 7/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.054, test=-0.099) total time=   5.4s
# [CV 8/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.054, test=-0.093) total time=   5.4s
# [CV 9/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.056, test=-0.090) total time=   5.4s
# [CV 10/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=-0.054, test=-0.098) total time=   5.5s
# [CV 1/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.102, test=-0.123) total time=   5.2s
# [CV 2/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.102, test=-0.133) total time=   5.2s
# [CV 3/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.104, test=-0.131) total time=   5.1s
# [CV 4/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.102, test=-0.124) total time=   5.3s
# [CV 5/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.101, test=-0.120) total time=   5.3s
# [CV 6/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.101, test=-0.126) total time=   5.3s
# [CV 7/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.103, test=-0.126) total time=   5.4s
# [CV 8/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.099, test=-0.130) total time=   5.3s
# [CV 9/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.100, test=-0.118) total time=   5.2s
# [CV 10/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=-0.100, test=-0.131) total time=   5.2s
# [CV 1/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.128, test=-0.138) total time=   5.0s
# [CV 2/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.132, test=-0.165) total time=   5.1s
# [CV 3/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.132, test=-0.143) total time=   5.0s
# [CV 4/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.133, test=-0.148) total time=   4.9s
# [CV 5/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.129, test=-0.132) total time=   5.0s
# [CV 6/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.133, test=-0.143) total time=   5.1s
# [CV 7/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.134, test=-0.146) total time=   5.1s
# [CV 8/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.130, test=-0.156) total time=   5.0s
# [CV 9/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.129, test=-0.136) total time=   5.1s
# [CV 10/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=-0.131, test=-0.150) total time=   5.2s
# [CV 1/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.047, test=-0.089) total time=   4.1s
# [CV 2/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.047, test=-0.095) total time=   3.9s
# [CV 3/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.046, test=-0.081) total time=   3.9s
# [CV 4/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.049, test=-0.088) total time=   3.9s
# [CV 5/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.048, test=-0.092) total time=   3.9s
# [CV 6/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.045, test=-0.088) total time=   3.9s
# [CV 7/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.048, test=-0.081) total time=   3.9s
# [CV 8/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.047, test=-0.086) total time=   3.9s
# [CV 9/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.048, test=-0.080) total time=   4.0s
# [CV 10/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.048, test=-0.093) total time=   4.0s
# [CV 1/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.097, test=-0.114) total time=   3.7s
# [CV 2/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.095, test=-0.126) total time=   3.8s
# [CV 3/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.095, test=-0.115) total time=   3.7s
# [CV 4/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.095, test=-0.115) total time=   3.6s
# [CV 5/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.094, test=-0.114) total time=   3.7s
# [CV 6/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.096, test=-0.119) total time=   3.7s
# [CV 7/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.096, test=-0.118) total time=   3.7s
# [CV 8/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.095, test=-0.122) total time=   3.6s
# [CV 9/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.094, test=-0.106) total time=   3.7s
# [CV 10/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.096, test=-0.123) total time=   3.7s
# [CV 1/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.126, test=-0.133) total time=   3.6s
# [CV 2/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.126, test=-0.158) total time=   3.6s
# [CV 3/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.128, test=-0.142) total time=   3.6s
# [CV 4/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.128, test=-0.144) total time=   3.5s
# [CV 5/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.126, test=-0.133) total time=   3.6s
# [CV 6/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.127, test=-0.142) total time=   3.6s
# [CV 7/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.128, test=-0.138) total time=   3.6s
# [CV 8/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.125, test=-0.149) total time=   3.6s
# [CV 9/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.125, test=-0.133) total time=   3.6s
# [CV 10/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.128, test=-0.151) total time=   3.6s
# [CV 1/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.048, test=-0.086) total time=   4.3s
# [CV 2/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.047, test=-0.097) total time=   4.4s
# [CV 3/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.048, test=-0.081) total time=   4.3s
# [CV 4/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.049, test=-0.091) total time=   4.2s
# [CV 5/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.047, test=-0.085) total time=   4.4s
# [CV 6/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.048, test=-0.086) total time=   4.4s
# [CV 7/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.047, test=-0.085) total time=   4.4s
# [CV 8/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.047, test=-0.088) total time=   4.4s
# [CV 9/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.049, test=-0.083) total time=   4.3s
# [CV 10/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.049, test=-0.089) total time=   4.4s
# [CV 1/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.096, test=-0.115) total time=   4.2s
# [CV 2/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.095, test=-0.131) total time=   4.1s
# [CV 3/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.096, test=-0.116) total time=   4.1s
# [CV 4/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.096, test=-0.117) total time=   4.1s
# [CV 5/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.094, test=-0.114) total time=   4.2s
# [CV 6/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.095, test=-0.121) total time=   4.2s
# [CV 7/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.098, test=-0.117) total time=   4.2s
# [CV 8/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.095, test=-0.125) total time=   4.2s
# [CV 9/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.096, test=-0.108) total time=   4.3s
# [CV 10/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.094, test=-0.120) total time=   4.1s
# [CV 1/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.126, test=-0.131) total time=   3.9s
# [CV 2/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.129, test=-0.164) total time=   4.0s
# [CV 3/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.125, test=-0.141) total time=   4.0s
# [CV 4/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.130, test=-0.147) total time=   4.0s
# [CV 5/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.127, test=-0.133) total time=   4.5s
# [CV 6/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.129, test=-0.143) total time=   4.0s
# [CV 7/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.130, test=-0.139) total time=   3.9s
# [CV 8/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.127, test=-0.154) total time=   3.9s
# [CV 9/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.125, test=-0.133) total time=   4.0s
# [CV 10/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.128, test=-0.147) total time=   4.1s
# [CV 1/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.048, test=-0.092) total time=   4.8s
# [CV 2/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.048, test=-0.096) total time=   4.8s
# [CV 3/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.048, test=-0.084) total time=   4.7s
# [CV 4/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.050, test=-0.088) total time=   4.7s
# [CV 5/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.047, test=-0.088) total time=   4.8s
# [CV 6/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.048, test=-0.092) total time=   4.9s
# [CV 7/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.048, test=-0.089) total time=   4.6s
# [CV 8/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.047, test=-0.085) total time=   4.8s
# [CV 9/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.049, test=-0.080) total time=   4.6s
# [CV 10/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.047, test=-0.091) total time=   4.8s
# [CV 1/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.099, test=-0.118) total time=   4.4s
# [CV 2/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.096, test=-0.130) total time=   4.3s
# [CV 3/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.097, test=-0.122) total time=   4.4s
# [CV 4/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.098, test=-0.118) total time=   4.4s
# [CV 5/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.096, test=-0.116) total time=   4.6s
# [CV 6/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.097, test=-0.124) total time=   4.4s
# [CV 7/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.098, test=-0.117) total time=   4.5s
# [CV 8/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.097, test=-0.124) total time=   4.5s
# [CV 9/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.097, test=-0.112) total time=   4.5s
# [CV 10/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.097, test=-0.125) total time=   4.4s
# [CV 1/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.126, test=-0.137) total time=   4.3s
# [CV 2/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.129, test=-0.158) total time=   4.3s
# [CV 3/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.128, test=-0.141) total time=   4.8s
# [CV 4/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.131, test=-0.149) total time=   5.0s
# [CV 5/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.126, test=-0.130) total time=   4.5s
# [CV 6/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.128, test=-0.142) total time=   4.2s
# [CV 7/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.128, test=-0.137) total time=   4.1s
# [CV 8/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.128, test=-0.149) total time=   4.1s
# [CV 9/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.127, test=-0.133) total time=   4.2s
# [CV 10/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.132, test=-0.157) total time=   4.1s
# [CV 1/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.048, test=-0.088) total time=   4.9s
# [CV 2/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.048, test=-0.097) total time=   5.0s
# [CV 3/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.048, test=-0.084) total time=   4.9s
# [CV 4/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.050, test=-0.090) total time=   4.9s
# [CV 5/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.047, test=-0.090) total time=   4.9s
# [CV 6/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.048, test=-0.090) total time=   5.1s
# [CV 7/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.048, test=-0.089) total time=   5.0s
# [CV 8/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.048, test=-0.088) total time=   5.0s
# [CV 9/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.049, test=-0.085) total time=   5.0s
# [CV 10/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.048, test=-0.094) total time=   5.0s
# [CV 1/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.097, test=-0.119) total time=   5.1s
# [CV 2/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.098, test=-0.131) total time=   5.3s
# [CV 3/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.099, test=-0.123) total time=   4.7s
# [CV 4/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.097, test=-0.120) total time=   4.7s
# [CV 5/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.098, test=-0.117) total time=   4.8s
# [CV 6/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.098, test=-0.123) total time=   4.8s
# [CV 7/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.098, test=-0.122) total time=   4.9s
# [CV 8/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.097, test=-0.128) total time=   4.8s
# [CV 9/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.099, test=-0.116) total time=   4.7s
# [CV 10/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.100, test=-0.125) total time=   4.6s
# [CV 1/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.127, test=-0.139) total time=   4.4s
# [CV 2/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.131, test=-0.164) total time=   4.5s
# [CV 3/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.131, test=-0.144) total time=   4.5s
# [CV 4/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.130, test=-0.150) total time=   4.5s
# [CV 5/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.129, test=-0.135) total time=   4.5s
# [CV 6/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.128, test=-0.142) total time=   4.4s
# [CV 7/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.132, test=-0.139) total time=   4.4s
# [CV 8/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.128, test=-0.149) total time=   4.4s
# [CV 9/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.127, test=-0.137) total time=   4.5s
# [CV 10/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.131, test=-0.151) total time=   4.6s
# [CV 1/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.048, test=-0.090) total time=   5.2s
# [CV 2/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.049, test=-0.098) total time=   5.3s
# [CV 3/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.049, test=-0.086) total time=   5.2s
# [CV 4/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.051, test=-0.093) total time=   5.4s
# [CV 5/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.049, test=-0.091) total time=   5.5s
# [CV 6/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.048, test=-0.093) total time=   5.3s
# [CV 7/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.049, test=-0.090) total time=   5.5s
# [CV 8/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.048, test=-0.089) total time=   5.2s
# [CV 9/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.050, test=-0.083) total time=   5.3s
# [CV 10/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=-0.048, test=-0.091) total time=   5.4s
# [CV 1/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.125) total time=   5.1s
# [CV 2/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.098, test=-0.135) total time=   5.0s
# [CV 3/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.101, test=-0.130) total time=   5.0s
# [CV 4/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.125) total time=   5.1s
# [CV 5/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.099, test=-0.116) total time=   4.9s
# [CV 6/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.098, test=-0.124) total time=   5.0s
# [CV 7/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.121) total time=   5.0s
# [CV 8/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.096, test=-0.127) total time=   5.0s
# [CV 9/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.098, test=-0.114) total time=   5.0s
# [CV 10/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=-0.100, test=-0.128) total time=   5.0s
# [CV 1/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.128, test=-0.141) total time=   4.8s
# [CV 2/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.133, test=-0.165) total time=   4.7s
# [CV 3/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.131, test=-0.144) total time=   4.7s
# [CV 4/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.148) total time=   4.7s
# [CV 5/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.128, test=-0.134) total time=   4.7s
# [CV 6/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.129, test=-0.142) total time=   4.8s
# [CV 7/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.130, test=-0.143) total time=   4.8s
# [CV 8/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.131, test=-0.157) total time=   4.6s
# [CV 9/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.128, test=-0.137) total time=   4.8s
# [CV 10/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.150) total time=   4.9s
# [CV 1/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.048, test=-0.088) total time=   5.6s
# [CV 2/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.048, test=-0.100) total time=   5.7s
# [CV 3/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.046, test=-0.083) total time=   5.8s
# [CV 4/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.051, test=-0.094) total time=   5.7s
# [CV 5/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.049, test=-0.092) total time=   5.4s
# [CV 6/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.049, test=-0.094) total time=   5.7s
# [CV 7/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.049, test=-0.088) total time=   5.6s
# [CV 8/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.048, test=-0.089) total time=   5.5s
# [CV 9/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.050, test=-0.086) total time=   5.6s
# [CV 10/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=-0.049, test=-0.095) total time=   5.9s
# [CV 1/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.099, test=-0.122) total time=   5.4s
# [CV 2/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.099, test=-0.135) total time=   5.4s
# [CV 3/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.099, test=-0.123) total time=   5.4s
# [CV 4/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.100, test=-0.119) total time=   5.3s
# [CV 5/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.100, test=-0.121) total time=   5.4s
# [CV 6/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.098, test=-0.122) total time=   5.3s
# [CV 7/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.100, test=-0.121) total time=   5.3s
# [CV 8/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.100, test=-0.128) total time=   5.3s
# [CV 9/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.099, test=-0.115) total time=   5.3s
# [CV 10/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=-0.100, test=-0.128) total time=   5.3s
# [CV 1/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.128, test=-0.139) total time=   5.0s
# [CV 2/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.133, test=-0.163) total time=   5.1s
# [CV 3/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.130, test=-0.144) total time=   5.2s
# [CV 4/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.133, test=-0.152) total time=   5.2s
# [CV 5/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.131, test=-0.134) total time=   5.1s
# [CV 6/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.132, test=-0.147) total time=   5.0s
# [CV 7/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.131, test=-0.143) total time=   5.3s
# [CV 8/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.131, test=-0.153) total time=   5.1s
# [CV 9/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.130, test=-0.140) total time=   5.0s
# [CV 10/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=-0.132, test=-0.152) total time=   5.2s
# [CV 1/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.043, test=-0.083) total time=   4.0s
# [CV 2/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.042, test=-0.093) total time=   4.1s
# [CV 3/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.041, test=-0.079) total time=   4.0s
# [CV 4/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.043, test=-0.085) total time=   4.1s
# [CV 5/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.043, test=-0.088) total time=   4.0s
# [CV 6/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.042, test=-0.087) total time=   4.1s
# [CV 7/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.042, test=-0.080) total time=   4.2s
# [CV 8/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.042, test=-0.080) total time=   4.2s
# [CV 9/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.044, test=-0.076) total time=   5.4s
# [CV 10/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.042, test=-0.084) total time=   4.4s
# [CV 1/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.094, test=-0.117) total time=   4.0s
# [CV 2/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.093, test=-0.126) total time=   4.0s
# [CV 3/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.092, test=-0.115) total time=   4.1s
# [CV 4/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.093, test=-0.115) total time=   4.1s
# [CV 5/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.093, test=-0.110) total time=   3.9s
# [CV 6/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.092, test=-0.117) total time=   4.1s
# [CV 7/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.093, test=-0.112) total time=   4.0s
# [CV 8/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.093, test=-0.121) total time=   3.9s
# [CV 9/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.093, test=-0.105) total time=   4.1s
# [CV 10/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.093, test=-0.123) total time=   4.1s
# [CV 1/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.126, test=-0.133) total time=   4.0s
# [CV 2/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.126, test=-0.158) total time=   3.9s
# [CV 3/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.127, test=-0.141) total time=   3.8s
# [CV 4/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.128, test=-0.147) total time=   3.7s
# [CV 5/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.124, test=-0.130) total time=   3.6s
# [CV 6/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.125, test=-0.141) total time=   3.8s
# [CV 7/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.126, test=-0.136) total time=   3.6s
# [CV 8/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.126, test=-0.148) total time=   3.6s
# [CV 9/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.126, test=-0.132) total time=   3.6s
# [CV 10/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.128, test=-0.150) total time=   3.6s
# [CV 1/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.043, test=-0.086) total time=   4.3s
# [CV 2/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.042, test=-0.090) total time=   4.4s
# [CV 3/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.043, test=-0.079) total time=   4.4s
# [CV 4/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.044, test=-0.088) total time=   4.4s
# ...
# [CV 3/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.126, test=-0.139) total time=   2.9s
# [CV 4/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.128, test=-0.146) total time=   2.9s
# [CV 5/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.125, test=-0.130) total time=   3.2s
# [CV 6/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.125, test=-0.139) total time=   3.0s
# [CV 7/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.128, test=-0.138) total time=   3.1s
# [CV 8/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.126, test=-0.149) total time=   3.0s
# [CV 9/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.125, test=-0.134) total time=   3.2s
# [CV 10/10] END max_depth=21, max_features=11, min_samples_split=100;, score=(train=-0.129, test=-0.154) total time=   3.2s
# [CV 1/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.033, test=-0.080) total time=   3.8s
# [CV 2/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.033, test=-0.092) total time=   3.8s
# [CV 3/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.032, test=-0.078) total time=   3.7s
# [CV 4/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.033, test=-0.084) total time=   3.6s
# [CV 5/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.032, test=-0.084) total time=   3.8s
# [CV 6/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.032, test=-0.083) total time=   3.9s
# [CV 7/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.033, test=-0.079) total time=   3.9s
# [CV 8/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.033, test=-0.081) total time=   3.9s
# [CV 9/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.034, test=-0.075) total time=   3.8s
# [CV 10/10] END max_depth=21, max_features=12, min_samples_split=10;, score=(train=-0.033, test=-0.081) total time=   3.8s
# [CV 1/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.094, test=-0.118) total time=   3.6s
# [CV 2/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.091, test=-0.128) total time=   3.4s
# [CV 3/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.094, test=-0.118) total time=   3.4s
# [CV 4/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.093, test=-0.120) total time=   3.4s
# [CV 5/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.092, test=-0.114) total time=   3.5s
# [CV 6/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.093, test=-0.121) total time=   3.6s
# [CV 7/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.093, test=-0.117) total time=   3.8s
# [CV 8/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.094, test=-0.126) total time=   3.8s
# [CV 9/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.093, test=-0.108) total time=   4.4s
# [CV 10/10] END max_depth=21, max_features=12, min_samples_split=50;, score=(train=-0.094, test=-0.124) total time=   4.6s
# [CV 1/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.126, test=-0.135) total time=   3.8s
# [CV 2/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.127, test=-0.159) total time=   3.7s
# [CV 3/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.128, test=-0.141) total time=   3.9s
# [CV 4/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.131, test=-0.148) total time=   4.1s
# [CV 5/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.127, test=-0.135) total time=   4.2s
# [CV 6/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.126, test=-0.141) total time=   4.1s
# [CV 7/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.128, test=-0.140) total time=   4.2s
# [CV 8/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.127, test=-0.153) total time=   4.1s
# [CV 9/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.125, test=-0.133) total time=   4.1s
# [CV 10/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.129, test=-0.148) total time=   4.1s
# [CV 1/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.033, test=-0.082) total time=   4.9s
# [CV 2/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.033, test=-0.093) total time=   5.0s
# [CV 3/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.033, test=-0.078) total time=   5.1s
# [CV 4/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.034, test=-0.083) total time=   4.9s
# [CV 5/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.033, test=-0.084) total time=   4.9s
# [CV 6/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.033, test=-0.084) total time=   4.9s
# [CV 7/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.034, test=-0.080) total time=   5.0s
# [CV 8/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.032, test=-0.085) total time=   5.0s
# [CV 9/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.035, test=-0.077) total time=   5.1s
# [CV 10/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.033, test=-0.084) total time=   4.7s
# [CV 1/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.095, test=-0.120) total time=   4.6s
# [CV 2/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.094, test=-0.131) total time=   5.9s
# [CV 3/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.096, test=-0.119) total time=   5.4s
# [CV 4/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.095, test=-0.119) total time=   5.2s
# [CV 5/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.095, test=-0.114) total time=   5.3s
# [CV 6/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.093, test=-0.122) total time=   5.3s
# [CV 7/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.094, test=-0.119) total time=   5.5s
# [CV 8/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.094, test=-0.128) total time=   5.1s
# [CV 9/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.093, test=-0.111) total time=   5.1s
# [CV 10/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.097, test=-0.126) total time=   5.1s
# [CV 1/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.128, test=-0.137) total time=   4.9s
# [CV 2/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.130, test=-0.163) total time=   6.2s
# [CV 3/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.127, test=-0.141) total time=   4.8s
# [CV 4/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.131, test=-0.150) total time=   3.8s
# [CV 5/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.128, test=-0.131) total time=   3.7s
# [CV 6/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.127, test=-0.139) total time=   3.9s
# [CV 7/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.130, test=-0.140) total time=   3.7s
# [CV 8/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.128, test=-0.156) total time=   3.8s
# [CV 9/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.127, test=-0.136) total time=   4.0s
# [CV 10/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.129, test=-0.150) total time=   4.1s
# [CV 1/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.033, test=-0.085) total time=   5.1s
# [CV 2/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.032, test=-0.092) total time=   5.2s
# [CV 3/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.032, test=-0.081) total time=   5.6s
# [CV 4/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.035, test=-0.086) total time=   4.6s
# [CV 5/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.033, test=-0.086) total time=   5.7s
# [CV 6/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.032, test=-0.086) total time=   6.1s
# [CV 7/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.033, test=-0.080) total time=   5.4s
# [CV 8/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.032, test=-0.083) total time=   5.4s
# [CV 9/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.034, test=-0.077) total time=   5.4s
# [CV 10/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=-0.034, test=-0.087) total time=   5.3s
# [CV 1/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.096, test=-0.121) total time=   4.9s
# [CV 2/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.094, test=-0.134) total time=   5.0s
# [CV 3/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.097, test=-0.121) total time=   5.1s
# [CV 4/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.097, test=-0.121) total time=   4.9s
# [CV 5/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.095, test=-0.116) total time=   5.0s
# [CV 6/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.096, test=-0.121) total time=   4.9s
# [CV 7/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.094, test=-0.118) total time=   5.0s
# [CV 8/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.096, test=-0.126) total time=   5.1s
# [CV 9/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.096, test=-0.109) total time=   5.0s
# [CV 10/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=-0.095, test=-0.126) total time=   4.9s
# [CV 1/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.127, test=-0.137) total time=   4.8s
# [CV 2/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.131, test=-0.162) total time=   4.8s
# [CV 3/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.131, test=-0.145) total time=   4.8s
# [CV 4/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.133, test=-0.152) total time=   4.7s
# [CV 5/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.128, test=-0.132) total time=   4.6s
# [CV 6/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.146) total time=   4.8s
# [CV 7/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.144) total time=   4.8s
# [CV 8/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.128, test=-0.153) total time=   4.6s
# [CV 9/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.128, test=-0.139) total time=   4.9s
# [CV 10/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=-0.132, test=-0.150) total time=   4.8s
# [CV 1/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.032, test=-0.085) total time=   5.7s
# [CV 2/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.033, test=-0.094) total time=   5.7s
# [CV 3/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.032, test=-0.081) total time=   5.6s
# [CV 4/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.035, test=-0.089) total time=   5.8s
# [CV 5/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.033, test=-0.087) total time=   5.7s
# [CV 6/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.032, test=-0.087) total time=   5.6s
# [CV 7/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.033, test=-0.082) total time=   5.7s
# [CV 8/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.033, test=-0.089) total time=   5.9s
# [CV 9/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.034, test=-0.079) total time=   6.0s
# [CV 10/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=-0.034, test=-0.087) total time=   5.8s
# [CV 1/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.096, test=-0.122) total time=   5.1s
# [CV 2/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.096, test=-0.133) total time=   5.3s
# [CV 3/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.098, test=-0.123) total time=   5.3s
# [CV 4/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.096, test=-0.119) total time=   5.4s
# [CV 5/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.096, test=-0.117) total time=   5.2s
# [CV 6/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.096, test=-0.127) total time=   5.3s
# [CV 7/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.097, test=-0.123) total time=   5.2s
# [CV 8/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.096, test=-0.128) total time=   5.4s
# [CV 9/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.094, test=-0.112) total time=   5.3s
# [CV 10/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=-0.097, test=-0.128) total time=   5.4s
# [CV 1/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.129, test=-0.141) total time=   4.9s
# [CV 2/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.133, test=-0.162) total time=   5.0s
# [CV 3/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.129, test=-0.141) total time=   5.1s
# [CV 4/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.134, test=-0.149) total time=   5.0s
# [CV 5/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.130, test=-0.133) total time=   4.9s
# [CV 6/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.130, test=-0.144) total time=   4.9s
# [CV 7/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.131, test=-0.142) total time=   5.0s
# [CV 8/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.129, test=-0.158) total time=   5.0s
# [CV 9/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.129, test=-0.136) total time=   5.1s
# [CV 10/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=-0.132, test=-0.153) total time=   5.1s
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [16, 17, 18, 19, 20, 21],
#                          'max_features': [10, 11, 12, 13, 14, 15],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
random_forest.best_params_
# Out:
# {'max_depth': 21, 'max_features': 10, 'min_samples_split': 10}

# %%
clf=RandomForestClassifier(min_samples_split= 10,
                           max_features=10,
                           max_depth=9)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=9, max_features=10, min_samples_split=10)

# %%
y_pred_clf_test= clf.predict(X_test)
y_pred_clf_train= clf.predict(X_train)

# %%
results_random_forest = metricas(y_test, y_pred_clf_test, y_train, y_pred_clf_train, "Random Forest" )
results_random_forest
# Out:
#    accuracy  precision    recall        f1    kapppa    set         modelo
# 0  0.834377   0.805375  0.884986  0.843306  0.668499   test  Random Forest
# 1  0.852771   0.817950  0.906845  0.860107  0.705598  train  Random Forest

# %%
matriz_logistica = matriz_confusion(y_test, y_pred_clf_test, y_test.shape[0])
matriz_logistica
# Out:
#         No    Yes
# No   40.01   9.63
# Yes   3.90  46.46

# %%
df_all = pd.concat([results_logistic_regression, results_decission_tree1, results_decission_tree2, results_random_forest])

# %%
df_all
# Out:
#    accuracy  precision    recall        f1    kapppa    set  \
# 0  0.821540   0.831683  0.809450  0.820416  0.643131   test
# 1  0.831833   0.836785  0.823728  0.830205  0.663656  train
# 0  0.902630   0.894977  0.913895  0.904337  0.805220   test
# 1  1.000000   1.000000  1.000000  1.000000  1.000000  train
# 0  0.891515   0.879207  0.909543  0.894118  0.782965   test
# 1  0.948145   0.934591  0.963538  0.948844  0.896295  train
# 0  0.864746   0.828356  0.922599  0.872941  0.729255   test
# 1  0.884275   0.844348  0.941739  0.890388  0.768598  train
#
#                 modelo
# 0  Logistic Regression
# 1  Logistic Regression
# 0     Decission Tree I
# 1     Decission Tree I
# 0    Decission Tree II
# 1    Decission Tree II
# 0        Random Forest
# 1        Random Forest
