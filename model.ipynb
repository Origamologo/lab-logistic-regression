# %%
import pandas as pd
import numpy as np

from imblearn.combine import SMOTETomek
from imblearn.combine import SMOTEENN

# librerías para crear el modelo
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn import tree

# para calcular las métricas
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import f1_score 
from sklearn.metrics import cohen_kappa_score


from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier


from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
df_yesno_scaled = pd.read_csv('data/df_yesno_scaled.csv')

# %%
df_yesno_scaled[df_yesno_scaled['Offer Accepted']== 'No'].shape
# Out:
# (0, 14)

# %% [markdown]
# # Imbalance
# There is a great imbalance between the Yes and No in 'Offer Accepted' column. To deal with this we'll combine upsampling and downsampling techniques that generate synthetic data points of minority class samples in the neighborhood of minority class samples and then removing samples which do not agree “enough” with their neighboorhood.

# %%
df_yesno_scaled.columns
# Out:
# Index(['Offer Accepted', '# Credit Cards Held', 'Household Size',
#        'Reward_Air Miles', 'Reward_Cash Back', 'Reward_Points',
#        'Mailer Type_Letter', 'Mailer Type_Postcard', 'Income Level_High',
#        'Income Level_Low', 'Income Level_Medium', 'Credit Rating_High',
#        'Credit Rating_Low', 'Credit Rating_Medium'],
#       dtype='object')

# %%
X = df_yesno_scaled[['# Credit Cards Held', 'Household Size',
       'Reward_Air Miles', 'Reward_Cash Back', 'Reward_Points',
       'Mailer Type_Letter', 'Mailer Type_Postcard', 'Income Level_High',
       'Income Level_Low', 'Income Level_Medium', 'Credit Rating_High',
       'Credit Rating_Low', 'Credit Rating_Medium']]
y = df_yesno_scaled['Offer Accepted']

# %%
smt = SMOTETomek()
X_resampled, y_resampled = smt.fit_resample(X, y)

# %%
y_resampled.value_counts()
# Out:
# 1    16469
# 0    16469
# Name: Offer Accepted, dtype: int64

# %% [markdown]
# # Model

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size = 0.2, 
                                                    random_state = 80)

# %%
y_train.describe()
# Out:
# count    26350.000000
# mean         0.498330
# std          0.500007
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: Offer Accepted, dtype: float64

# %%
y_test.describe()
# Out:
# count    6588.000000
# mean        0.506679
# std         0.499993
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Offer Accepted, dtype: float64

# %%
def metricas(clases_reales_test, clases_predichas_test, clases_reales_train, clases_predichas_train, modelo):
    
    # para el test
    accuracy_test = accuracy_score(clases_reales_test, clases_predichas_test)
    precision_test = precision_score(clases_reales_test, clases_predichas_test)
    recall_test = recall_score(clases_reales_test, clases_predichas_test)
    f1_test = f1_score(clases_reales_test, clases_predichas_test)
    kappa_test = cohen_kappa_score(clases_reales_test, clases_predichas_test)

    # para el train
    accuracy_train = accuracy_score(clases_reales_train, clases_predichas_train)
    precision_train = precision_score(clases_reales_train, clases_predichas_train)
    recall_train = recall_score(clases_reales_train, clases_predichas_train)
    f1_train = f1_score(clases_reales_train, clases_predichas_train)
    kappa_train = cohen_kappa_score(clases_reales_train, clases_predichas_train)
    

    
    df = pd.DataFrame({"accuracy": [accuracy_test, accuracy_train], 
                       "precision": [precision_test, precision_train],
                       "recall": [recall_test, recall_train], 
                       "f1": [f1_test, f1_train],
                       "kapppa": [kappa_test, kappa_train],
                       "set": ["test", "train"]})
    
    df["modelo"] = modelo
    return df

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression(max_iter = 100000)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=100000)

# %%
y_pred_lr_test = lr.predict(X_test)
y_pred_lr_train = lr.predict(X_train)

# %% [markdown]
# Let's check the accuracy of our model on the test set.

# %%
def matriz_confusion(clases_reales, clases_predichas, total_filas_test):
    mat_lr = confusion_matrix(clases_reales, clases_predichas)

    df = pd.DataFrame(mat_lr, columns = ["No", "Yes"], index = ["No", "Yes"])
    df = ((df / total_filas_test) * 100).round(2)
    return df

# %%
results_logistic_regression = metricas(y_test, y_pred_lr_test, y_train, y_pred_lr_train, "Logistic Regression" )
results_logistic_regression
# Out:
#    accuracy  precision    recall        f1    kapppa    set  \
# 0  0.724347   0.726084  0.732175  0.729117  0.448534   test
# 1  0.731044   0.725455  0.740538  0.732919  0.462119  train
#
#                 modelo
# 0  Logistic Regression
# 1  Logistic Regression

# %%
matriz_logistica = matriz_confusion(y_test, y_pred_lr_test, y_test.shape[0])
matriz_logistica
# Out:
#        Yes    No
# Yes  35.34  14.0
# No   13.57  37.1

# %% [markdown]
# ### Decision Tree

# %%
arbol = DecisionTreeClassifier()
arbol.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
max_features = np.sqrt(len(X_train.columns))
max_features
# Out:
# 3.605551275463989

# %%
y_pred_train_dt = arbol.predict(X_train)
y_pred_test_dt = arbol.predict(X_test)

# %%
results_decission_tree1 = metricas(y_test, y_pred_test_dt,y_train, y_pred_train_dt, "Decission Tree I" )
results_decission_tree1
# Out:
#    accuracy  precision    recall        f1    kapppa    set            modelo
# 0  0.854888   0.844618  0.874476  0.859288  0.709585   test  Decission Tree I
# 1  0.864554   0.844949  0.891859  0.867771  0.729155  train  Decission Tree I

# %%
matriz_logistica = matriz_confusion(y_test, y_pred_test_dt, y_test.shape[0])
matriz_logistica
# Out:
#         No    Yes
# No   41.18   8.15
# Yes   6.36  44.31

# %%
print(arbol.tree_.max_depth)
# Out:
# 20

# %%
param = {"max_depth": [16, 17, 18, 19, 20, 21],
         "min_samples_split": [10, 50, 100],
         "max_features": [10, 11, 12, 13, 14, 15]}

arbol2 = GridSearchCV(
        estimator = DecisionTreeClassifier(), 
        param_grid = param, 
        verbose = 3, 
        cv = 10, 
        return_train_score = True, 
        scoring = "neg_mean_squared_error")

# %%
arbol2.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# [CV 1/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.140, test=-0.140) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.138, test=-0.146) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.138, test=-0.145) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.162) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.138, test=-0.149) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.148) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.152) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.158) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.139, test=-0.146) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.158) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.163, test=-0.162) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.159, test=-0.169) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.159, test=-0.165) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.158, test=-0.179) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.160, test=-0.171) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.156, test=-0.162) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.161, test=-0.174) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.161, test=-0.183) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.164, test=-0.178) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=10, min_samples_split=50;, score=(train=-0.159, test=-0.178) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.186, test=-0.187) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.185, test=-0.201) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.184, test=-0.184) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.186, test=-0.203) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.183, test=-0.189) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.182, test=-0.188) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.183, test=-0.196) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.183, test=-0.204) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.180, test=-0.192) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=10, min_samples_split=100;, score=(train=-0.182, test=-0.201) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.138, test=-0.140) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.138, test=-0.146) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.140, test=-0.145) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.138, test=-0.160) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.146) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.151) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.153) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.136, test=-0.159) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.139, test=-0.145) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.160) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.160, test=-0.161) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.161, test=-0.164) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.163, test=-0.170) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.158, test=-0.183) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.159, test=-0.173) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.156, test=-0.164) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.161, test=-0.174) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.160, test=-0.186) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.161, test=-0.175) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=11, min_samples_split=50;, score=(train=-0.159, test=-0.177) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.184, test=-0.195) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.183, test=-0.192) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.182, test=-0.181) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.180, test=-0.195) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.179, test=-0.187) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.186, test=-0.186) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.176, test=-0.190) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.177, test=-0.197) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.183, test=-0.195) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=11, min_samples_split=100;, score=(train=-0.183, test=-0.202) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.139, test=-0.142) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.138, test=-0.142) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.138, test=-0.144) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.136, test=-0.158) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.138, test=-0.146) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.137, test=-0.149) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.137, test=-0.153) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.138, test=-0.160) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.140, test=-0.146) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=12, min_samples_split=10;, score=(train=-0.136, test=-0.157) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.159, test=-0.162) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.157, test=-0.164) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.160, test=-0.163) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.158, test=-0.181) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.156, test=-0.168) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.157, test=-0.161) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.155, test=-0.168) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.158, test=-0.180) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.157, test=-0.164) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=12, min_samples_split=50;, score=(train=-0.157, test=-0.180) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.185, test=-0.195) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.178, test=-0.191) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.183, test=-0.192) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.177, test=-0.192) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.178, test=-0.191) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.180, test=-0.185) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.176, test=-0.192) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.180, test=-0.204) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.181, test=-0.192) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=12, min_samples_split=100;, score=(train=-0.178, test=-0.198) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.139, test=-0.140) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.138, test=-0.141) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.138, test=-0.142) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.136, test=-0.156) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.138, test=-0.146) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.137, test=-0.149) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.138, test=-0.153) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.136, test=-0.160) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.138, test=-0.143) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=13, min_samples_split=10;, score=(train=-0.137, test=-0.157) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.160, test=-0.164) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.156, test=-0.163) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.158, test=-0.160) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.157, test=-0.177) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.155, test=-0.168) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.156, test=-0.161) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.155, test=-0.167) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.157, test=-0.179) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.159, test=-0.167) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=13, min_samples_split=50;, score=(train=-0.156, test=-0.176) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.181, test=-0.191) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.180, test=-0.193) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.179, test=-0.182) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.177, test=-0.191) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.177, test=-0.188) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.179, test=-0.181) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.177, test=-0.192) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.178, test=-0.201) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.179, test=-0.192) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=13, min_samples_split=100;, score=(train=-0.176, test=-0.199) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=16, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.141) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.139) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.142) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.136, test=-0.161) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.147) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.150) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.136, test=-0.152) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.135, test=-0.160) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.140) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=10, min_samples_split=10;, score=(train=-0.136, test=-0.157) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.164, test=-0.162) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.159, test=-0.159) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.160, test=-0.166) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.162, test=-0.183) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.159, test=-0.172) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.159, test=-0.169) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.157, test=-0.168) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.156, test=-0.178) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.160, test=-0.171) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=10, min_samples_split=50;, score=(train=-0.157, test=-0.181) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.187, test=-0.197) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.180, test=-0.191) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.183, test=-0.184) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.182, test=-0.201) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.181, test=-0.194) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.183, test=-0.191) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.181, test=-0.196) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.182, test=-0.206) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.186, test=-0.199) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=10, min_samples_split=100;, score=(train=-0.183, test=-0.202) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.139, test=-0.141) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.140) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.138, test=-0.142) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.135, test=-0.157) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.147) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.136, test=-0.148) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.136, test=-0.151) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.135, test=-0.158) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.142) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=11, min_samples_split=10;, score=(train=-0.135, test=-0.157) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.160, test=-0.162) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.156, test=-0.162) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.156, test=-0.156) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.156, test=-0.176) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.156, test=-0.170) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.158, test=-0.165) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.156, test=-0.167) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.157, test=-0.179) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.162, test=-0.172) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=11, min_samples_split=50;, score=(train=-0.157, test=-0.176) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.182, test=-0.192) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.184, test=-0.192) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.183, test=-0.180) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.178, test=-0.200) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.179, test=-0.181) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.180, test=-0.185) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.184, test=-0.197) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.183, test=-0.201) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.183, test=-0.194) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=11, min_samples_split=100;, score=(train=-0.182, test=-0.202) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.138, test=-0.138) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.137, test=-0.140) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.137, test=-0.142) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.135, test=-0.157) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.137, test=-0.148) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.136, test=-0.150) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.136, test=-0.153) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.136, test=-0.160) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.137, test=-0.143) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=12, min_samples_split=10;, score=(train=-0.135, test=-0.156) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.160, test=-0.163) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.155, test=-0.160) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.158, test=-0.164) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.158, test=-0.179) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.156, test=-0.170) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.156, test=-0.159) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.155, test=-0.166) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.157, test=-0.182) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.158, test=-0.166) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=12, min_samples_split=50;, score=(train=-0.155, test=-0.174) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.181, test=-0.190) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.178, test=-0.187) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.179, test=-0.187) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.180, test=-0.197) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.179, test=-0.189) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.180, test=-0.182) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.177, test=-0.197) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.177, test=-0.201) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.179, test=-0.192) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=12, min_samples_split=100;, score=(train=-0.180, test=-0.201) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.138, test=-0.139) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.137, test=-0.139) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.136, test=-0.142) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.135, test=-0.156) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.137, test=-0.146) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.135, test=-0.149) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.136, test=-0.152) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.135, test=-0.159) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.137, test=-0.142) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=13, min_samples_split=10;, score=(train=-0.135, test=-0.155) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.160, test=-0.162) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.156, test=-0.162) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.158, test=-0.160) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.157, test=-0.177) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.155, test=-0.168) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.156, test=-0.161) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.155, test=-0.167) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.157, test=-0.179) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.159, test=-0.167) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=13, min_samples_split=50;, score=(train=-0.155, test=-0.176) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.181, test=-0.190) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.180, test=-0.193) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.179, test=-0.182) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.177, test=-0.191) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.177, test=-0.188) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.179, test=-0.181) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.176, test=-0.192) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.178, test=-0.201) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.179, test=-0.192) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=13, min_samples_split=100;, score=(train=-0.176, test=-0.199) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=17, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.140) total time=   0.0s
# [CV 2/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.143) total time=   0.0s
# [CV 3/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.145) total time=   0.0s
# [CV 4/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.135, test=-0.162) total time=   0.0s
# [CV 5/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.136, test=-0.146) total time=   0.0s
# [CV 6/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.136, test=-0.150) total time=   0.0s
# [CV 7/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.136, test=-0.152) total time=   0.0s
# [CV 8/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.135, test=-0.160) total time=   0.0s
# [CV 9/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.137, test=-0.143) total time=   0.0s
# [CV 10/10] END max_depth=18, max_features=10, min_samples_split=10;, score=(train=-0.136, test=-0.159) total time=   0.0s
# [CV 1/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.160, test=-0.161) total time=   0.0s
# [CV 2/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.162, test=-0.164) total time=   0.0s
# [CV 3/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.161, test=-0.162) total time=   0.0s
# [CV 4/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.161, test=-0.187) total time=   0.0s
# [CV 5/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.157, test=-0.167) total time=   0.0s
# [CV 6/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.159, test=-0.169) total time=   0.0s
# [CV 7/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.155, test=-0.169) total time=   0.0s
# [CV 8/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.158, test=-0.181) total time=   0.0s
# [CV 9/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.159, test=-0.171) total time=   0.0s
# [CV 10/10] END max_depth=18, max_features=10, min_samples_split=50;, score=(train=-0.158, test=-0.180) total time=   0.0s
# [CV 1/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.181, test=-0.183) total time=   0.0s
# [CV 2/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.182, test=-0.184) total time=   0.0s
# [CV 3/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.182, test=-0.184) total time=   0.0s
# [CV 4/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.180, test=-0.202) total time=   0.0s
# [CV 5/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.182, test=-0.187) total time=   0.0s
# [CV 6/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.185, test=-0.186) total time=   0.0s
# [CV 7/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.178, test=-0.193) total time=   0.0s
# [CV 8/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.182, test=-0.208) total time=   0.0s
# [CV 9/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.184, test=-0.200) total time=   0.0s
# [CV 10/10] END max_depth=18, max_features=10, min_samples_split=100;, score=(train=-0.182, test=-0.205) total time=   0.0s
# [CV 1/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.140) total time=   0.0s
# [CV 2/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.141) total time=   0.0s
# [CV 3/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.144) total time=   0.0s
# [CV 4/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.135, test=-0.158) total time=   0.0s
# [CV 5/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.136, test=-0.144) total time=   0.0s
# [CV 6/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.136, test=-0.147) total time=   0.0s
# [CV 7/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.136, test=-0.151) total time=   0.0s
# [CV 8/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.135, test=-0.159) total time=   0.0s
# [CV 9/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.137, test=-0.142) total time=   0.0s
# [CV 10/10] END max_depth=18, max_features=11, min_samples_split=10;, score=(train=-0.135, test=-0.155) total time=   0.0s
# ...
# [CV 3/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.179, test=-0.178) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.179, test=-0.200) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.181, test=-0.183) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.182, test=-0.185) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.183, test=-0.200) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.179, test=-0.196) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.179, test=-0.194) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=12, min_samples_split=100;, score=(train=-0.183, test=-0.203) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.137, test=-0.139) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.137, test=-0.140) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.136, test=-0.142) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.135, test=-0.156) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.136, test=-0.144) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.135, test=-0.149) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.136, test=-0.152) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.135, test=-0.159) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.137, test=-0.142) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=13, min_samples_split=10;, score=(train=-0.135, test=-0.155) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.160, test=-0.162) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.156, test=-0.163) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.158, test=-0.160) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.157, test=-0.177) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.155, test=-0.168) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.156, test=-0.161) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.155, test=-0.167) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.157, test=-0.179) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.158, test=-0.167) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=13, min_samples_split=50;, score=(train=-0.155, test=-0.176) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.181, test=-0.190) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.180, test=-0.193) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.179, test=-0.182) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.177, test=-0.191) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.177, test=-0.188) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.179, test=-0.181) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.176, test=-0.192) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.178, test=-0.201) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.179, test=-0.192) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=13, min_samples_split=100;, score=(train=-0.176, test=-0.199) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=14, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=14, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=14, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=15, min_samples_split=10;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=15, min_samples_split=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 4/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 5/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 6/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 7/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 8/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 9/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 10/10] END max_depth=21, max_features=15, min_samples_split=100;, score=(train=nan, test=nan) total time=   0.0s
# c:\Users\mituc\anaconda3\envs\py39\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 360 fits failed out of a total of 1080.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\mituc\anaconda3\envs\py39\lib\site-packages\sklearn\model_selection\_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\mituc\anaconda3\envs\py39\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "c:\Users\mituc\anaconda3\envs\py39\lib\site-packages\sklearn\tree\_classes.py", line 308, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\mituc\anaconda3\envs\py39\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [-0.15036053 -0.17206831 -0.1944592  -0.15055028 -0.17271347 -0.19199241
#  -0.14960152 -0.16907021 -0.19301708 -0.14872865 -0.16823529 -0.19089184
#          nan         nan         nan         nan         nan         nan
#  -0.1488425  -0.17092979 -0.19612903 -0.1483871  -0.1683112  -0.19233397
#  -0.14872865 -0.1683112  -0.19240987 -0.14796964 -0.16796964 -0.19085389
#          nan         nan         nan         nan         nan         nan
#  -0.14994307 -0.17108159 -0.19332068 -0.14815939 -0.16990512 -0.19392789
#  -0.14796964 -0.16925996 -0.19225806 -0.14766603 -0.16796964 -0.19085389
#          nan         nan         nan         nan         nan         nan
#  -0.1487666  -0.17259962 -0.19313093 -0.14880455 -0.16967742 -0.19210626
#  -0.14812144 -0.17028463 -0.19259962 -0.14759013 -0.16789374 -0.19081594
#          nan         nan         nan         nan         nan         nan
#  -0.1487666  -0.17176471 -0.19358634 -0.14819734 -0.16975332 -0.19271347
#  -0.14789374 -0.16899431 -0.19134725 -0.14766603 -0.16793169 -0.19085389
#          nan         nan         nan         nan         nan         nan
#  -0.14891841 -0.17199241 -0.19483871 -0.14819734 -0.16990512 -0.19214421
#  -0.14793169 -0.16888046 -0.19328273 -0.14770398 -0.16796964 -0.19081594
#          nan         nan         nan         nan         nan         nan]
#   warnings.warn(
# c:\Users\mituc\anaconda3\envs\py39\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the train scores are non-finite: [-0.13775669 -0.16020662 -0.18336918 -0.13777778 -0.15978073 -0.18127346
#  -0.13763019 -0.15742357 -0.17962893 -0.13733924 -0.15688383 -0.1783386
#          nan         nan         nan         nan         nan         nan
#  -0.1364242  -0.15931689 -0.18282943 -0.13652962 -0.15759646 -0.18194392
#  -0.13641999 -0.15689226 -0.17911448 -0.1362471  -0.15676998 -0.1783133
#          nan         nan         nan         nan         nan         nan
#  -0.13628505 -0.15906388 -0.18192705 -0.13619228 -0.15841029 -0.18158549
#  -0.13618385 -0.1578326  -0.17983976 -0.13600675 -0.15671094 -0.1783133
#          nan         nan         nan         nan         nan         nan
#  -0.13621758 -0.1600759  -0.18305292 -0.13621758 -0.15791271 -0.18143791
#  -0.13611217 -0.15815728 -0.18040902 -0.13600675 -0.15673203 -0.1783133
#          nan         nan         nan         nan         nan         nan
#  -0.1362218  -0.15952773 -0.18388362 -0.13605735 -0.15873076 -0.18147586
#  -0.13598145 -0.15744466 -0.17945604 -0.13600675 -0.15670251 -0.17832174
#          nan         nan         nan         nan         nan         nan
#  -0.13631457 -0.15968796 -0.18343243 -0.13623867 -0.1580856  -0.18030782
#  -0.13612482 -0.15771453 -0.18092768 -0.13600675 -0.15673203 -0.1783133
#          nan         nan         nan         nan         nan         nan]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [16, 17, 18, 19, 20, 21],
#                          'max_features': [10, 11, 12, 13, 14, 15],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
arbol2.best_params_
# Out:
# {'max_depth': 19, 'max_features': 13, 'min_samples_split': 10}

# %%
arbol3 = DecisionTreeClassifier( max_depth = 19, max_features = 13, min_samples_split=10)
arbol3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=19, max_features=13, min_samples_split=10)

# %%
y_pred_train_dt = arbol3.predict(X_train)
y_pred_test_dt = arbol3.predict(X_test)

# %%
results_decission_tree2 = metricas(y_test, y_pred_test_dt, y_train, y_pred_train_dt, "Decission Tree II" )
results_decission_tree2
# Out:
#    accuracy  precision    recall        f1    kapppa    set             modelo
# 0  0.854281   0.843642  0.874476  0.858782  0.708365   test  Decission Tree II
# 1  0.864023   0.844246  0.891630  0.867291  0.728093  train  Decission Tree II

# %%
matriz_logistica = matriz_confusion(y_test, y_pred_test_dt, y_test.shape[0])
matriz_logistica
# Out:
#         No    Yes
# No   41.12   8.21
# Yes   6.36  44.31

# %% [markdown]
# ### Random Forest

# %%
random_forest = GridSearchCV(
        estimator = RandomForestClassifier(), 
        param_grid = param, 
        verbose = 3, 
        cv = 10, 
        return_train_score = True, 
        scoring = "neg_mean_squared_error")

# %%
random_forest.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [CV 1/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.298, test=-0.291) total time=   0.2s
# [CV 2/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.291, test=-0.293) total time=   0.2s
# [CV 3/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.294, test=-0.288) total time=   0.2s
# [CV 4/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.294, test=-0.303) total time=   0.2s
# [CV 5/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.297, test=-0.288) total time=   0.2s
# [CV 6/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.299, test=-0.315) total time=   0.2s
# [CV 7/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.286, test=-0.299) total time=   0.1s
# [CV 8/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.294, test=-0.309) total time=   0.1s
# [CV 9/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.301, test=-0.290) total time=   0.1s
# [CV 10/10] END max_depth=2, max_features=1, min_samples_split=10;, score=(train=-0.299, test=-0.284) total time=   0.2s
# [CV 1/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.300, test=-0.291) total time=   0.1s
# [CV 2/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.304, test=-0.298) total time=   0.2s
# [CV 3/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.299, test=-0.296) total time=   0.1s
# [CV 4/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.294, test=-0.302) total time=   0.1s
# [CV 5/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.290, test=-0.281) total time=   0.2s
# [CV 6/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.295, test=-0.313) total time=   0.1s
# [CV 7/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.292, test=-0.306) total time=   0.1s
# [CV 8/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.297, test=-0.312) total time=   0.1s
# [CV 9/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.306, test=-0.293) total time=   0.1s
# [CV 10/10] END max_depth=2, max_features=1, min_samples_split=50;, score=(train=-0.301, test=-0.295) total time=   0.1s
# [CV 1/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.297, test=-0.291) total time=   0.1s
# [CV 2/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.292, test=-0.298) total time=   0.1s
# [CV 3/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.291, test=-0.286) total time=   0.1s
# [CV 4/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.292, test=-0.302) total time=   0.1s
# [CV 5/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.294, test=-0.283) total time=   0.2s
# [CV 6/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.292, test=-0.316) total time=   0.3s
# [CV 7/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.289, test=-0.294) total time=   0.2s
# [CV 8/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.294, test=-0.307) total time=   0.2s
# [CV 9/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.298, test=-0.287) total time=   0.3s
# [CV 10/10] END max_depth=2, max_features=1, min_samples_split=100;, score=(train=-0.293, test=-0.284) total time=   0.3s
# [CV 1/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.302, test=-0.300) total time=   0.4s
# [CV 2/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.305, test=-0.305) total time=   0.3s
# [CV 3/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.300, test=-0.293) total time=   0.3s
# [CV 4/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.298, test=-0.307) total time=   0.3s
# [CV 5/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.296, test=-0.281) total time=   0.3s
# [CV 6/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.301, test=-0.314) total time=   0.3s
# [CV 7/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.300, test=-0.309) total time=   0.3s
# [CV 8/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.297, test=-0.312) total time=   0.3s
# [CV 9/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.301, test=-0.289) total time=   0.3s
# [CV 10/10] END max_depth=2, max_features=2, min_samples_split=10;, score=(train=-0.296, test=-0.283) total time=   0.3s
# [CV 1/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.296, test=-0.296) total time=   0.3s
# [CV 2/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.296, test=-0.295) total time=   0.3s
# [CV 3/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.305, test=-0.301) total time=   0.5s
# [CV 4/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.305, test=-0.317) total time=   0.5s
# [CV 5/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.292, test=-0.280) total time=   0.3s
# [CV 6/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.313, test=-0.325) total time=   0.4s
# [CV 7/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.294, test=-0.301) total time=   0.4s
# [CV 8/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.296, test=-0.312) total time=   0.5s
# [CV 9/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.302, test=-0.296) total time=   0.4s
# [CV 10/10] END max_depth=2, max_features=2, min_samples_split=50;, score=(train=-0.298, test=-0.288) total time=   0.4s
# [CV 1/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.298, test=-0.297) total time=   0.4s
# [CV 2/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.300, test=-0.296) total time=   0.3s
# [CV 3/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.297, test=-0.289) total time=   0.4s
# [CV 4/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.302, test=-0.309) total time=   0.4s
# [CV 5/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.302, test=-0.295) total time=   0.3s
# [CV 6/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.303, test=-0.320) total time=   0.3s
# [CV 7/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.296, test=-0.306) total time=   0.3s
# [CV 8/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.295, test=-0.311) total time=   0.3s
# [CV 9/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.294, test=-0.282) total time=   0.3s
# [CV 10/10] END max_depth=2, max_features=2, min_samples_split=100;, score=(train=-0.302, test=-0.288) total time=   0.3s
# [CV 1/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.298, test=-0.303) total time=   0.4s
# [CV 2/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.302, test=-0.301) total time=   0.3s
# [CV 3/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.304, test=-0.301) total time=   0.3s
# [CV 4/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.300, test=-0.309) total time=   0.3s
# [CV 5/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.301, test=-0.299) total time=   0.3s
# [CV 6/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.303, test=-0.314) total time=   0.4s
# [CV 7/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.295, test=-0.301) total time=   0.3s
# [CV 8/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.302, test=-0.314) total time=   0.4s
# [CV 9/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.298, test=-0.292) total time=   0.3s
# [CV 10/10] END max_depth=2, max_features=3, min_samples_split=10;, score=(train=-0.307, test=-0.295) total time=   0.4s
# [CV 1/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.297, test=-0.301) total time=   0.3s
# [CV 2/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.302, test=-0.300) total time=   0.3s
# [CV 3/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.305, test=-0.302) total time=   0.3s
# [CV 4/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.301, test=-0.307) total time=   0.3s
# [CV 5/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.302, test=-0.293) total time=   0.4s
# [CV 6/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.296, test=-0.311) total time=   0.3s
# [CV 7/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.300, test=-0.306) total time=   0.4s
# [CV 8/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.300, test=-0.313) total time=   0.3s
# [CV 9/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.303, test=-0.293) total time=   0.3s
# [CV 10/10] END max_depth=2, max_features=3, min_samples_split=50;, score=(train=-0.301, test=-0.291) total time=   0.3s
# [CV 1/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.297, test=-0.287) total time=   0.3s
# [CV 2/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.304, test=-0.308) total time=   0.3s
# [CV 3/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.297, test=-0.289) total time=   0.3s
# [CV 4/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.299, test=-0.307) total time=   0.3s
# [CV 5/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.300, test=-0.302) total time=   0.4s
# [CV 6/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.302, test=-0.313) total time=   0.4s
# [CV 7/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.297, test=-0.305) total time=   0.3s
# [CV 8/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.299, test=-0.312) total time=   0.3s
# [CV 9/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.302, test=-0.293) total time=   0.3s
# [CV 10/10] END max_depth=2, max_features=3, min_samples_split=100;, score=(train=-0.303, test=-0.289) total time=   0.3s
# [CV 1/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.309, test=-0.301) total time=   0.3s
# [CV 2/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.307, test=-0.308) total time=   0.3s
# [CV 3/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.302, test=-0.295) total time=   0.4s
# [CV 4/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.306, test=-0.313) total time=   0.4s
# [CV 5/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.306, test=-0.304) total time=   0.4s
# [CV 6/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.306, test=-0.320) total time=   0.3s
# [CV 7/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.304, test=-0.312) total time=   0.4s
# [CV 8/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.306, test=-0.313) total time=   0.4s
# [CV 9/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.316, test=-0.306) total time=   0.5s
# [CV 10/10] END max_depth=2, max_features=4, min_samples_split=10;, score=(train=-0.309, test=-0.297) total time=   0.6s
# [CV 1/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.306, test=-0.298) total time=   0.4s
# [CV 2/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.307, test=-0.309) total time=   0.4s
# [CV 3/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.309, test=-0.306) total time=   0.5s
# [CV 4/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.309, test=-0.315) total time=   0.4s
# [CV 5/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.308, test=-0.306) total time=   0.4s
# [CV 6/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.318, test=-0.328) total time=   0.4s
# [CV 7/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.305, test=-0.319) total time=   0.4s
# [CV 8/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.306, test=-0.310) total time=   0.3s
# [CV 9/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.308, test=-0.300) total time=   0.4s
# [CV 10/10] END max_depth=2, max_features=4, min_samples_split=50;, score=(train=-0.306, test=-0.297) total time=   0.5s
# [CV 1/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.314, test=-0.310) total time=   0.4s
# [CV 2/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.302, test=-0.296) total time=   0.4s
# [CV 3/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.300, test=-0.292) total time=   0.4s
# [CV 4/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.307, test=-0.310) total time=   0.4s
# [CV 5/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.302, test=-0.302) total time=   0.4s
# [CV 6/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.305, test=-0.318) total time=   0.4s
# [CV 7/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.300, test=-0.305) total time=   0.4s
# [CV 8/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.310, test=-0.325) total time=   0.3s
# [CV 9/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.307, test=-0.297) total time=   0.4s
# [CV 10/10] END max_depth=2, max_features=4, min_samples_split=100;, score=(train=-0.304, test=-0.296) total time=   0.4s
# [CV 1/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.288, test=-0.285) total time=   0.3s
# [CV 2/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.282, test=-0.285) total time=   0.3s
# [CV 3/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.286, test=-0.276) total time=   0.3s
# [CV 4/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.290, test=-0.297) total time=   0.3s
# [CV 5/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.286, test=-0.282) total time=   0.3s
# [CV 6/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.285, test=-0.300) total time=   0.3s
# [CV 7/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.284, test=-0.299) total time=   0.3s
# [CV 8/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.281, test=-0.293) total time=   0.3s
# [CV 9/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.286, test=-0.273) total time=   0.5s
# [CV 10/10] END max_depth=3, max_features=1, min_samples_split=10;, score=(train=-0.295, test=-0.282) total time=   0.4s
# [CV 1/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.285, test=-0.283) total time=   0.3s
# [CV 2/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.287, test=-0.290) total time=   0.4s
# [CV 3/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.281, test=-0.276) total time=   0.4s
# [CV 4/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.278, test=-0.284) total time=   0.3s
# [CV 5/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.285, test=-0.277) total time=   0.3s
# [CV 6/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.290, test=-0.300) total time=   0.3s
# [CV 7/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.292, test=-0.299) total time=   0.3s
# [CV 8/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.287, test=-0.298) total time=   0.3s
# [CV 9/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.291, test=-0.280) total time=   0.3s
# [CV 10/10] END max_depth=3, max_features=1, min_samples_split=50;, score=(train=-0.287, test=-0.282) total time=   0.3s
# [CV 1/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.288, test=-0.279) total time=   0.3s
# [CV 2/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.291, test=-0.296) total time=   0.3s
# [CV 3/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.285, test=-0.271) total time=   0.3s
# [CV 4/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.283, test=-0.290) total time=   0.3s
# [CV 5/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.294, test=-0.285) total time=   0.3s
# [CV 6/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.294, test=-0.306) total time=   0.4s
# [CV 7/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.287, test=-0.298) total time=   0.4s
# [CV 8/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.282, test=-0.291) total time=   0.6s
# [CV 9/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.290, test=-0.277) total time=   0.5s
# [CV 10/10] END max_depth=3, max_features=1, min_samples_split=100;, score=(train=-0.283, test=-0.274) total time=   0.5s
# [CV 1/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.293, test=-0.291) total time=   0.6s
# [CV 2/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.294, test=-0.294) total time=   0.5s
# [CV 3/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.294, test=-0.280) total time=   0.6s
# [CV 4/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.296, test=-0.309) total time=   0.2s
# [CV 5/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.294, test=-0.286) total time=   0.2s
# [CV 6/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.295, test=-0.311) total time=   0.2s
# [CV 7/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.300, test=-0.305) total time=   0.2s
# [CV 8/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.294, test=-0.307) total time=   0.2s
# [CV 9/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.295, test=-0.285) total time=   0.2s
# [CV 10/10] END max_depth=3, max_features=2, min_samples_split=10;, score=(train=-0.294, test=-0.278) total time=   0.3s
# [CV 1/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.290, test=-0.291) total time=   0.2s
# [CV 2/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.293, test=-0.296) total time=   0.2s
# [CV 3/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.294, test=-0.280) total time=   0.2s
# [CV 4/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.292, test=-0.304) total time=   0.2s
# [CV 5/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.296, test=-0.288) total time=   0.2s
# [CV 6/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.296, test=-0.312) total time=   0.2s
# [CV 7/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.295, test=-0.304) total time=   0.2s
# [CV 8/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.296, test=-0.308) total time=   0.2s
# [CV 9/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.295, test=-0.282) total time=   0.3s
# [CV 10/10] END max_depth=3, max_features=2, min_samples_split=50;, score=(train=-0.297, test=-0.285) total time=   0.2s
# [CV 1/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.291, test=-0.290) total time=   0.2s
# [CV 2/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.300, test=-0.298) total time=   0.2s
# [CV 3/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.295, test=-0.283) total time=   0.2s
# [CV 4/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.290, test=-0.299) total time=   0.3s
# [CV 5/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.293, test=-0.279) total time=   0.3s
# [CV 6/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.293, test=-0.309) total time=   0.3s
# [CV 7/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.291, test=-0.301) total time=   0.3s
# [CV 8/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.293, test=-0.309) total time=   0.2s
# [CV 9/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.299, test=-0.287) total time=   0.2s
# [CV 10/10] END max_depth=3, max_features=2, min_samples_split=100;, score=(train=-0.294, test=-0.277) total time=   0.3s
# [CV 1/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.299, test=-0.297) total time=   0.3s
# [CV 2/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.295, test=-0.293) total time=   0.2s
# [CV 3/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.298, test=-0.290) total time=   0.3s
# [CV 4/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.301, test=-0.307) total time=   0.2s
# [CV 5/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.293, test=-0.287) total time=   0.2s
# [CV 6/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.294, test=-0.312) total time=   0.3s
# [CV 7/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.297, test=-0.304) total time=   0.2s
# [CV 8/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.292, test=-0.305) total time=   0.2s
# [CV 9/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.300, test=-0.292) total time=   0.3s
# [CV 10/10] END max_depth=3, max_features=3, min_samples_split=10;, score=(train=-0.299, test=-0.286) total time=   0.3s
# [CV 1/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.294, test=-0.292) total time=   0.2s
# [CV 2/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.296, test=-0.295) total time=   0.2s
# [CV 3/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.294, test=-0.282) total time=   0.2s
# [CV 4/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.302, test=-0.310) total time=   0.3s
# [CV 5/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.298, test=-0.298) total time=   0.2s
# [CV 6/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.295, test=-0.311) total time=   0.2s
# [CV 7/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.292, test=-0.303) total time=   0.3s
# [CV 8/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.299, test=-0.313) total time=   0.2s
# [CV 9/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.298, test=-0.291) total time=   0.3s
# [CV 10/10] END max_depth=3, max_features=3, min_samples_split=50;, score=(train=-0.299, test=-0.287) total time=   0.3s
# [CV 1/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.294, test=-0.293) total time=   0.2s
# [CV 2/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.295, test=-0.297) total time=   0.2s
# [CV 3/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.298, test=-0.285) total time=   0.2s
# [CV 4/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.293, test=-0.303) total time=   0.2s
# [CV 5/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.296, test=-0.288) total time=   0.2s
# [CV 6/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.295, test=-0.312) total time=   0.2s
# [CV 7/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.297, test=-0.302) total time=   0.2s
# [CV 8/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.296, test=-0.310) total time=   0.2s
# [CV 9/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.303, test=-0.294) total time=   0.2s
# [CV 10/10] END max_depth=3, max_features=3, min_samples_split=100;, score=(train=-0.301, test=-0.286) total time=   0.3s
# [CV 1/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.298, test=-0.294) total time=   0.3s
# [CV 2/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.299, test=-0.295) total time=   0.3s
# [CV 3/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.303, test=-0.299) total time=   0.3s
# [CV 4/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.295, test=-0.304) total time=   0.3s
# [CV 5/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.302, test=-0.290) total time=   0.3s
# [CV 6/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.296, test=-0.312) total time=   0.3s
# [CV 7/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.299, test=-0.312) total time=   0.3s
# [CV 8/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.298, test=-0.308) total time=   0.3s
# [CV 9/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.298, test=-0.288) total time=   0.3s
# [CV 10/10] END max_depth=3, max_features=4, min_samples_split=10;, score=(train=-0.300, test=-0.288) total time=   0.3s
# [CV 1/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.295, test=-0.294) total time=   0.3s
# [CV 2/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.295, test=-0.291) total time=   0.3s
# [CV 3/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.297, test=-0.289) total time=   0.3s
# [CV 4/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.296, test=-0.305) total time=   0.3s
# [CV 5/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.293, test=-0.291) total time=   0.3s
# [CV 6/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.297, test=-0.315) total time=   0.3s
# [CV 7/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.296, test=-0.304) total time=   0.3s
# [CV 8/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.300, test=-0.311) total time=   0.3s
# [CV 9/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.293, test=-0.283) total time=   0.3s
# [CV 10/10] END max_depth=3, max_features=4, min_samples_split=50;, score=(train=-0.302, test=-0.294) total time=   0.3s
# [CV 1/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.303, test=-0.304) total time=   0.3s
# [CV 2/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.300, test=-0.299) total time=   0.3s
# [CV 3/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.295, test=-0.284) total time=   0.3s
# [CV 4/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.290, test=-0.298) total time=   0.3s
# [CV 5/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.294, test=-0.291) total time=   0.3s
# [CV 6/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.294, test=-0.311) total time=   0.3s
# [CV 7/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.299, test=-0.312) total time=   0.3s
# [CV 8/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.296, test=-0.310) total time=   0.3s
# [CV 9/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.296, test=-0.285) total time=   0.3s
# [CV 10/10] END max_depth=3, max_features=4, min_samples_split=100;, score=(train=-0.298, test=-0.283) total time=   0.3s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.274, test=-0.269) total time=   0.2s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.273, test=-0.279) total time=   0.2s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.278, test=-0.265) total time=   0.2s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.269, test=-0.273) total time=   0.2s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.273, test=-0.259) total time=   0.2s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.275, test=-0.288) total time=   0.2s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.280, test=-0.293) total time=   0.2s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.272, test=-0.283) total time=   0.2s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.274, test=-0.259) total time=   0.2s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.275, test=-0.263) total time=   0.2s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.274, test=-0.274) total time=   0.2s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.269, test=-0.272) total time=   0.2s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.271, test=-0.267) total time=   0.2s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.270, test=-0.276) total time=   0.2s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.272, test=-0.267) total time=   0.2s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.272, test=-0.282) total time=   0.2s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.272, test=-0.283) total time=   0.2s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.270, test=-0.285) total time=   0.2s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.279, test=-0.270) total time=   0.2s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.272, test=-0.266) total time=   0.2s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.269, test=-0.272) total time=   0.2s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.276, test=-0.283) total time=   0.2s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.271, test=-0.272) total time=   0.2s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.279, test=-0.287) total time=   0.2s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.277, test=-0.273) total time=   0.2s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.274, test=-0.289) total time=   0.2s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.275, test=-0.288) total time=   0.2s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.277, test=-0.292) total time=   0.2s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.273, test=-0.260) total time=   0.2s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.275, test=-0.266) total time=   0.2s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.287, test=-0.290) total time=   0.3s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.288, test=-0.286) total time=   0.2s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.281, test=-0.268) total time=   0.2s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.282, test=-0.290) total time=   0.3s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.285, test=-0.279) total time=   0.2s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.286, test=-0.306) total time=   0.2s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.280, test=-0.295) total time=   0.2s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.285, test=-0.294) total time=   0.3s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.288, test=-0.281) total time=   0.3s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.285, test=-0.271) total time=   0.3s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.291, test=-0.292) total time=   0.3s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.286, test=-0.287) total time=   0.3s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.284, test=-0.271) total time=   0.2s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.287, test=-0.294) total time=   0.2s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.286, test=-0.285) total time=   0.2s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.289, test=-0.307) total time=   0.2s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.285, test=-0.294) total time=   0.2s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.278, test=-0.287) total time=   0.3s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.284, test=-0.274) total time=   0.2s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.283, test=-0.276) total time=   0.3s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.287, test=-0.287) total time=   0.2s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.283, test=-0.283) total time=   0.2s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.285, test=-0.272) total time=   0.2s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.284, test=-0.293) total time=   0.2s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.287, test=-0.276) total time=   0.3s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.285, test=-0.298) total time=   0.2s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.284, test=-0.294) total time=   0.3s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.286, test=-0.300) total time=   0.3s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.288, test=-0.282) total time=   0.2s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.275, test=-0.268) total time=   0.2s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.293, test=-0.293) total time=   0.3s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.288, test=-0.284) total time=   0.3s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.290, test=-0.279) total time=   0.3s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.288, test=-0.298) total time=   0.3s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.289, test=-0.285) total time=   0.3s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.287, test=-0.306) total time=   0.3s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.288, test=-0.294) total time=   0.3s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.285, test=-0.297) total time=   0.3s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.287, test=-0.274) total time=   0.3s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.295, test=-0.281) total time=   0.3s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.285, test=-0.282) total time=   0.3s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.286, test=-0.285) total time=   0.3s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.291, test=-0.279) total time=   0.3s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.289, test=-0.299) total time=   0.3s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.290, test=-0.290) total time=   0.3s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.285, test=-0.297) total time=   0.3s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.286, test=-0.295) total time=   0.3s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.289, test=-0.301) total time=   0.3s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.291, test=-0.285) total time=   0.3s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.295, test=-0.279) total time=   0.3s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.293, test=-0.295) total time=   0.3s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.288, test=-0.281) total time=   0.3s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.290, test=-0.282) total time=   0.3s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.291, test=-0.303) total time=   0.3s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.284, test=-0.280) total time=   0.3s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.288, test=-0.302) total time=   0.3s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.291, test=-0.299) total time=   0.3s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.292, test=-0.305) total time=   0.3s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.293, test=-0.284) total time=   0.3s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.289, test=-0.275) total time=   0.3s
# [CV 1/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.290, test=-0.292) total time=   0.3s
# [CV 2/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.289, test=-0.283) total time=   0.3s
# [CV 3/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.292, test=-0.282) total time=   0.3s
# [CV 4/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.291, test=-0.302) total time=   0.3s
# [CV 5/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.292, test=-0.287) total time=   0.3s
# [CV 6/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.284, test=-0.299) total time=   0.3s
# [CV 7/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.290, test=-0.298) total time=   0.3s
# [CV 8/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.289, test=-0.302) total time=   0.3s
# [CV 9/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.292, test=-0.286) total time=   0.3s
# [CV 10/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.283, test=-0.273) total time=   0.3s
# [CV 1/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.288, test=-0.285) total time=   0.3s
# [CV 2/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.291, test=-0.288) total time=   0.3s
# [CV 3/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.290, test=-0.279) total time=   0.3s
# [CV 4/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.290, test=-0.301) total time=   0.3s
# [CV 5/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.289, test=-0.283) total time=   0.3s
# [CV 6/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.287, test=-0.304) total time=   0.3s
# [CV 7/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.288, test=-0.296) total time=   0.3s
# [CV 8/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.288, test=-0.301) total time=   0.3s
# [CV 9/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.290, test=-0.284) total time=   0.3s
# [CV 10/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.290, test=-0.280) total time=   0.3s
# [CV 1/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.292, test=-0.293) total time=   0.4s
# [CV 2/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.287, test=-0.284) total time=   0.3s
# [CV 3/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.292, test=-0.282) total time=   0.3s
# [CV 4/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.289, test=-0.301) total time=   0.3s
# [CV 5/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.287, test=-0.283) total time=   0.3s
# [CV 6/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.288, test=-0.305) total time=   0.3s
# [CV 7/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.288, test=-0.294) total time=   0.3s
# [CV 8/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.288, test=-0.300) total time=   0.3s
# [CV 9/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.288, test=-0.279) total time=   0.3s
# [CV 10/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.290, test=-0.279) total time=   0.3s
# [CV 1/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.246, test=-0.244) total time=   0.2s
# [CV 2/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.243, test=-0.241) total time=   0.2s
# [CV 3/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.244, test=-0.240) total time=   0.2s
# [CV 4/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.246, test=-0.258) total time=   0.3s
# [CV 5/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.240, test=-0.235) total time=   0.4s
# [CV 6/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.247, test=-0.262) total time=   0.3s
# [CV 7/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.254, test=-0.261) total time=   0.3s
# [CV 8/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.240, test=-0.256) total time=   0.3s
# [CV 9/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.248, test=-0.234) total time=   0.3s
# [CV 10/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.241, test=-0.245) total time=   0.3s
# [CV 1/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.246, test=-0.251) total time=   0.3s
# [CV 2/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.242, test=-0.242) total time=   0.3s
# [CV 3/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.242, test=-0.235) total time=   0.3s
# [CV 4/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.244, test=-0.256) total time=   0.3s
# [CV 5/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.249, test=-0.252) total time=   0.3s
# [CV 6/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.240, test=-0.262) total time=   0.3s
# [CV 7/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.242, test=-0.251) total time=   0.3s
# [CV 8/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.247, test=-0.262) total time=   0.3s
# [CV 9/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.247, test=-0.233) total time=   0.3s
# [CV 10/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.242, test=-0.250) total time=   0.3s
# [CV 1/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.245, test=-0.243) total time=   0.3s
# [CV 2/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.244, test=-0.246) total time=   0.3s
# [CV 3/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.249, test=-0.238) total time=   0.3s
# [CV 4/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.247, test=-0.257) total time=   0.2s
# [CV 5/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.251, test=-0.246) total time=   0.3s
# [CV 6/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.247, test=-0.261) total time=   0.2s
# [CV 7/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.243, test=-0.248) total time=   0.2s
# [CV 8/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.240, test=-0.256) total time=   0.3s
# [CV 9/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.247, test=-0.231) total time=   0.2s
# [CV 10/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.243, test=-0.252) total time=   0.3s
# [CV 1/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.245, test=-0.246) total time=   0.3s
# [CV 2/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.251, test=-0.255) total time=   0.3s
# [CV 3/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.250, test=-0.238) total time=   0.3s
# [CV 4/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.244, test=-0.255) total time=   0.3s
# [CV 5/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.250, test=-0.244) total time=   0.3s
# [CV 6/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.248, test=-0.267) total time=   0.3s
# [CV 7/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.254, test=-0.266) total time=   0.3s
# [CV 8/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.248, test=-0.261) total time=   0.3s
# [CV 9/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.256, test=-0.245) total time=   0.3s
# [CV 10/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.245, test=-0.244) total time=   0.3s
# [CV 1/10] END max_depth=6, max_features=2, min_samples_split=50;, score=(train=-0.254, test=-0.247) total time=   0.3s
# ...
# [CV 1/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.215, test=-0.217) total time=   0.9s
# [CV 2/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.212, test=-0.213) total time=   0.6s
# [CV 3/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.214, test=-0.206) total time=   0.7s
# [CV 4/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.216, test=-0.224) total time=   0.7s
# [CV 5/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.215, test=-0.213) total time=   0.6s
# [CV 6/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.216, test=-0.236) total time=   0.6s
# [CV 7/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.214, test=-0.222) total time=   0.7s
# [CV 8/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.211, test=-0.227) total time=   0.6s
# [CV 9/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.215, test=-0.212) total time=   0.6s
# [CV 10/10] END max_depth=8, max_features=4, min_samples_split=100;, score=(train=-0.214, test=-0.222) total time=   0.7s
# [CV 1/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.156, test=-0.166) total time=   0.5s
# [CV 2/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.156, test=-0.170) total time=   0.5s
# [CV 3/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.158, test=-0.165) total time=   0.5s
# [CV 4/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.156, test=-0.172) total time=   0.6s
# [CV 5/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.160, test=-0.170) total time=   0.5s
# [CV 6/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.157, test=-0.172) total time=   0.5s
# [CV 7/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.155, test=-0.165) total time=   0.5s
# [CV 8/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.157, test=-0.178) total time=   0.6s
# [CV 9/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.159, test=-0.154) total time=   0.5s
# [CV 10/10] END max_depth=10, max_features=1, min_samples_split=10;, score=(train=-0.158, test=-0.166) total time=   0.5s
# [CV 1/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.166, test=-0.177) total time=   0.5s
# [CV 2/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.168, test=-0.182) total time=   0.5s
# [CV 3/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.170, test=-0.178) total time=   0.4s
# [CV 4/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.168, test=-0.181) total time=   0.4s
# [CV 5/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.171, test=-0.181) total time=   0.3s
# [CV 6/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.166, test=-0.184) total time=   0.4s
# [CV 7/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.171, test=-0.181) total time=   0.4s
# [CV 8/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.165, test=-0.179) total time=   0.3s
# [CV 9/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.171, test=-0.167) total time=   0.4s
# [CV 10/10] END max_depth=10, max_features=1, min_samples_split=50;, score=(train=-0.166, test=-0.175) total time=   0.3s
# [CV 1/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.185, test=-0.193) total time=   0.3s
# [CV 2/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.185, test=-0.196) total time=   0.3s
# [CV 3/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.185, test=-0.190) total time=   0.3s
# [CV 4/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.184, test=-0.199) total time=   0.3s
# [CV 5/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.185, test=-0.189) total time=   0.4s
# [CV 6/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.184, test=-0.195) total time=   0.3s
# [CV 7/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.188, test=-0.195) total time=   0.3s
# [CV 8/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.187, test=-0.203) total time=   0.3s
# [CV 9/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.188, test=-0.179) total time=   0.3s
# [CV 10/10] END max_depth=10, max_features=1, min_samples_split=100;, score=(train=-0.185, test=-0.196) total time=   0.4s
# [CV 1/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.157, test=-0.169) total time=   0.5s
# [CV 2/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.161, test=-0.174) total time=   0.6s
# [CV 3/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.161, test=-0.166) total time=   0.5s
# [CV 4/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.160, test=-0.173) total time=   0.5s
# [CV 5/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.160, test=-0.172) total time=   0.5s
# [CV 6/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.158, test=-0.176) total time=   0.5s
# [CV 7/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.156, test=-0.165) total time=   0.5s
# [CV 8/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.159, test=-0.175) total time=   0.5s
# [CV 9/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.162, test=-0.157) total time=   0.5s
# [CV 10/10] END max_depth=10, max_features=2, min_samples_split=10;, score=(train=-0.160, test=-0.168) total time=   0.5s
# [CV 1/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.172, test=-0.183) total time=   0.5s
# [CV 2/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.172, test=-0.183) total time=   0.5s
# [CV 3/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.174, test=-0.176) total time=   0.5s
# [CV 4/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.172, test=-0.187) total time=   0.5s
# [CV 5/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.171, test=-0.177) total time=   0.5s
# [CV 6/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.174, test=-0.192) total time=   0.5s
# [CV 7/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.173, test=-0.181) total time=   0.5s
# [CV 8/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.171, test=-0.190) total time=   0.5s
# [CV 9/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.173, test=-0.170) total time=   0.5s
# [CV 10/10] END max_depth=10, max_features=2, min_samples_split=50;, score=(train=-0.169, test=-0.176) total time=   0.5s
# [CV 1/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.187, test=-0.195) total time=   0.5s
# [CV 2/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.185, test=-0.194) total time=   0.5s
# [CV 3/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.188, test=-0.190) total time=   0.5s
# [CV 4/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.186, test=-0.197) total time=   0.5s
# [CV 5/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.190, test=-0.197) total time=   0.5s
# [CV 6/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.187, test=-0.203) total time=   0.5s
# [CV 7/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.185, test=-0.188) total time=   0.5s
# [CV 8/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.188, test=-0.202) total time=   0.5s
# [CV 9/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.187, test=-0.181) total time=   0.5s
# [CV 10/10] END max_depth=10, max_features=2, min_samples_split=100;, score=(train=-0.186, test=-0.190) total time=   0.5s
# [CV 1/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.161, test=-0.170) total time=   0.6s
# [CV 2/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.161, test=-0.177) total time=   0.6s
# [CV 3/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.163, test=-0.165) total time=   0.7s
# [CV 4/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.161, test=-0.173) total time=   0.6s
# [CV 5/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.159, test=-0.167) total time=   0.6s
# [CV 6/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.162, test=-0.178) total time=   0.6s
# [CV 7/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.158, test=-0.166) total time=   0.6s
# [CV 8/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.159, test=-0.177) total time=   0.6s
# [CV 9/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.161, test=-0.162) total time=   0.6s
# [CV 10/10] END max_depth=10, max_features=3, min_samples_split=10;, score=(train=-0.162, test=-0.169) total time=   0.6s
# [CV 1/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.173, test=-0.186) total time=   0.6s
# [CV 2/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.171, test=-0.183) total time=   0.6s
# [CV 3/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.176, test=-0.176) total time=   0.6s
# [CV 4/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.171, test=-0.186) total time=   0.6s
# [CV 5/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.173, test=-0.178) total time=   0.6s
# [CV 6/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.172, test=-0.188) total time=   0.6s
# [CV 7/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.172, test=-0.177) total time=   0.6s
# [CV 8/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.173, test=-0.196) total time=   0.6s
# [CV 9/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.174, test=-0.172) total time=   0.6s
# [CV 10/10] END max_depth=10, max_features=3, min_samples_split=50;, score=(train=-0.177, test=-0.184) total time=   0.6s
# [CV 1/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.186, test=-0.197) total time=   0.6s
# [CV 2/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.186, test=-0.195) total time=   0.6s
# [CV 3/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.188, test=-0.189) total time=   0.6s
# [CV 4/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.186, test=-0.197) total time=   0.6s
# [CV 5/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.187, test=-0.191) total time=   0.6s
# [CV 6/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.187, test=-0.207) total time=   0.6s
# [CV 7/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.187, test=-0.193) total time=   0.6s
# [CV 8/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.188, test=-0.205) total time=   0.6s
# [CV 9/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.188, test=-0.186) total time=   0.6s
# [CV 10/10] END max_depth=10, max_features=3, min_samples_split=100;, score=(train=-0.190, test=-0.198) total time=   0.6s
# [CV 1/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.159, test=-0.171) total time=   0.7s
# [CV 2/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.163, test=-0.179) total time=   0.7s
# [CV 3/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.162, test=-0.167) total time=   0.7s
# [CV 4/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.160, test=-0.175) total time=   0.7s
# [CV 5/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.163, test=-0.174) total time=   0.7s
# [CV 6/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.162, test=-0.180) total time=   0.7s
# [CV 7/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.160, test=-0.167) total time=   0.7s
# [CV 8/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.161, test=-0.182) total time=   0.7s
# [CV 9/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.163, test=-0.159) total time=   0.7s
# [CV 10/10] END max_depth=10, max_features=4, min_samples_split=10;, score=(train=-0.162, test=-0.169) total time=   0.7s
# [CV 1/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.174, test=-0.187) total time=   0.7s
# [CV 2/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.173, test=-0.184) total time=   0.7s
# [CV 3/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.173, test=-0.176) total time=   0.7s
# [CV 4/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.171, test=-0.188) total time=   0.7s
# [CV 5/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.175, test=-0.180) total time=   0.7s
# [CV 6/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.174, test=-0.189) total time=   0.7s
# [CV 7/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.175, test=-0.179) total time=   0.6s
# [CV 8/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.173, test=-0.195) total time=   0.7s
# [CV 9/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.173, test=-0.166) total time=   0.7s
# [CV 10/10] END max_depth=10, max_features=4, min_samples_split=50;, score=(train=-0.172, test=-0.179) total time=   0.5s
# [CV 1/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.187, test=-0.198) total time=   0.5s
# [CV 2/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.188, test=-0.195) total time=   0.5s
# [CV 3/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.192, test=-0.189) total time=   0.5s
# [CV 4/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.186, test=-0.200) total time=   0.5s
# [CV 5/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.187, test=-0.193) total time=   0.5s
# [CV 6/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.187, test=-0.202) total time=   0.5s
# [CV 7/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.186, test=-0.190) total time=   0.5s
# [CV 8/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.187, test=-0.205) total time=   0.5s
# [CV 9/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.189, test=-0.189) total time=   0.5s
# [CV 10/10] END max_depth=10, max_features=4, min_samples_split=100;, score=(train=-0.188, test=-0.199) total time=   0.5s
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 3, 4, 6, 8, 10],
#                          'max_features': [1, 2, 3, 4],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
random_forest.best_params_
# Out:
# {'max_depth': 10, 'max_features': 1, 'min_samples_split': 10}

# %%
clf=RandomForestClassifier(min_samples_split= 10,
                           max_features=1,
                           max_depth=10)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, max_features=1, min_samples_split=10)

# %%
y_pred_clf_test= clf.predict(X_test)
y_pred_clf_train= clf.predict(X_train)

# %%
results_random_forest = metricas(y_test, y_pred_clf_test, y_train, y_pred_clf_train, "Random Forest" )
results_random_forest
# Out:
#    accuracy  precision    recall        f1    kapppa    set         modelo
# 0  0.835914   0.792585  0.915818  0.849757  0.671077   test  Random Forest
# 1  0.842011   0.792728  0.924758  0.853668  0.684194  train  Random Forest

# %%
matriz_logistica = matriz_confusion(y_test, y_pred_clf_test, y_test.shape[0])
matriz_logistica
# Out:
#        Yes     No
# Yes  37.19  12.14
# No    4.27  46.40

# %%
df_all = pd.concat([results_logistic_regression, results_decission_tree1, results_decission_tree2, results_random_forest])

# %%
df_all
# Out:
#    accuracy  precision    recall        f1    kapppa    set  \
# 0  0.724347   0.726084  0.732175  0.729117  0.448534   test
# 1  0.731044   0.725455  0.740538  0.732919  0.462119  train
# 0  0.854888   0.844618  0.874476  0.859288  0.709585   test
# 1  0.864554   0.844949  0.891859  0.867771  0.729155  train
# 0  0.854281   0.843642  0.874476  0.858782  0.708365   test
# 1  0.864023   0.844246  0.891630  0.867291  0.728093  train
# 0  0.835914   0.792585  0.915818  0.849757  0.671077   test
# 1  0.842011   0.792728  0.924758  0.853668  0.684194  train
#
#                 modelo
# 0  Logistic Regression
# 1  Logistic Regression
# 0     Decission Tree I
# 1     Decission Tree I
# 0    Decission Tree II
# 1    Decission Tree II
# 0        Random Forest
# 1        Random Forest
